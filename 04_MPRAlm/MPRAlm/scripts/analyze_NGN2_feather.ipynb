# %% [markdown]
# ## Find interesting results in MPRAlm results

# %%
import pandas as pd 
import yaml 

# load config file
with open("config.yaml", "r") as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

pd.read_feather(config["files"]["toptable"])
pd.read_feather(config["files"]["weights"])
