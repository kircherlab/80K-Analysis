# %% [markdown]
# #### Analyse here the difference between variant based and element based TFBS
# - Plot the upset plots of the upregulating and downregulating TFBS

# %%
# TODO: add the regioneReloaded results and TFBS enrichment/depletion analysis (tfbs set overlap)
pivot_table_enrichment_depletion_path = "/home/kisa/coding/80K_MPRA/remap_chipseq_pia/80k_results/regioneReloaded_sampling1000_ngn2_and_undiffWTC11_remap2022_combined_tfbs_pivot_presence_enrichment_depletion.csv"
combined_information_of_tfbs_with_enrichment_depletion_path = "/home/kisa/coding/80K_MPRA/remap_chipseq_pia/80k_results/regioneReloaded_sampling1000_ngn2_and_undiffWTC11_remap2022_combined_tfbs_presence_enrichment_depletion.csv"
