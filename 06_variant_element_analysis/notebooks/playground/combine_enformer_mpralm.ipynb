# %% [markdown]
# ## Combine enformer results and bcmpralm results
# - plan is to give clear numbers of variants and their origin
# - mpralm:
#   - `/home/kisa/coding/80K_MPRA/80K-Analysis/04_MPRAlm/MPRAlm/results/NGN2_output/mpralm/toptable_mpralm.csv`
# - enformer class:
#   - neuro
#     - ultra_rare: `/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/neuro.ultra-rare_enformer_class.tsv`
#     - singleton: `/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/neuro.singleton_enformer_class.tsv`
# - Goal logic:
#   - % and absolute number of analyzable sequences (compared to total number of variants + controls put in)
#   - % significant => enformer class distribution
#   - % positive => % high effect according to enformer
#   - % negative => % high effect according to enformer
# - idea: combine enformer class files first and combine then mpralm and enformer class (same id)?
#   1. combine enformer files: `/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/merged_enformer_class.tsv`
#   2. combine with mpralm table:
#     - add chrom pos ref alt identifier to both tables and merge with this id
#   3. Make analysis
#   4. Add all controls to MPRAlm
#   5. Which sequences have the highest difference

# %%
# combine files (enformer class)
# list all files in folder: do it in bash:

# first=1
# for f in /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cava.singleton_enformer_class.tsv /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/random.ultra-rare_enformer_class.tsv /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cardiac.singleton_enformer_class.tsv /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/neuro.ultra-rare_enformer_class.tsv /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/neuro.singleton_enformer_class.tsv /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cava.ultra-rare_enformer_class.tsv /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cardiac.ultra-rare_enformer_class.tsv
# do
#     if [ "$first" ]
#     then
#         cat "$f"
#         first=
#     else
#         cat "$f" | tail -n +2
#     fi
# done > /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/merged_enformer_class.tsv

# => merged_enformer_class.tsv


#### possible python solution

import os
import pandas as pd
enformer_file_list = os.listdir('/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class')
# add paths:
enformer_file_list = ['/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/' + file for file in enformer_file_list if 'merged' not in file]
# # check number of rows and sum up
# total_number = 0
# for file in enformer_file_list:
#     df = pd.read_csv(file, sep='\t')
#     total_number += df.shape[0]

# # check if /home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/merged_enformer_class.tsv has same number of rows
# # sanity check number of lines with header?
# merged_enformer_class = '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/merged_enformer_class.tsv'
# merged_enformer_class_df = pd.read_csv(merged_enformer_class, sep='\t')
# if total_number != merged_enformer_class_df.shape[0]:
#     # throw error number of rows do not match
#     raise ValueError('Number of rows do not match')
# else:
#     print('Santity check passed: merge of enformer class files successful')

# %%
enformer_file_list
# Out:
# ['/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cava.singleton_enformer_class.tsv',
#  '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/random.ultra-rare_enformer_class.tsv',
#  '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cardiac.singleton_enformer_class.tsv',
#  '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/neuro.ultra-rare_enformer_class.tsv',
#  '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/neuro.singleton_enformer_class.tsv',
#  '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cava.ultra-rare_enformer_class.tsv',
#  '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/cardiac.ultra-rare_enformer_class.tsv']

# %%
import pandas as pd

total_number_of_variants_in_design = 46458

enformer_class_path = '/home/kisa/coding/80K_MPRA/server_results/enformer_results/enformer_class/merged_enformer_class.tsv'
enformer_class = pd.read_csv(enformer_class_path, sep="\t")
# mpra_result_path = '/home/kisa/coding/80K_MPRA/80K-Analysis/04_MPRAlm/MPRAlm/results/NGN2_output/mpralm/toptable_mpralm.csv'
# mpra_result = pd.read_csv(mpra_result_path, sep=",", index_col=0)
mpra_result_path = '/home/kisa/coding/80K_MPRA/server_results/bc_MPRAlm/toptable_GC_Selvarajan_standardNGN2.tsv'
mpra_result = pd.read_csv(mpra_result_path, sep="\t")
mpra_result

# preprocess mpra_result: remove label on variant_id => ID => merge
mpra_result['ID'] = mpra_result['variant_id'].str.split(':').str[1]

# get total number of cardiac_neuro_cava_random variants in mpra_result
n_tested_vars = mpra_result[mpra_result['variant_id'].str.startswith('cardiac_neuro_cava_random')].shape[0]
n_tested_vars # 41284
# mpra_result.shape[0] # 41464
# Out:
# 41284

# %% [markdown]
# ### Quick questions:
# - how many of the MPRAlm results are significant?
# - how many are positive and how many are negative?
# - How does the p-value distribution look like? (with and without multiple testing correction)

# %%
mpra_result
# Out:
#           logFC   AveExpr          t       P.Value     adj.P.Val           B  \
# 0      1.456812  1.860281  16.887425  2.660743e-54  1.103250e-49  111.530180
# 1      1.606197  0.969005  12.616945  9.251426e-32  1.918006e-27   60.057828
# 2      1.531276  0.923153  12.197297  3.871885e-30  5.351462e-26   56.506252
# 3      0.907774  0.994476  11.422970  2.968129e-28  3.076763e-24   53.219004
# 4     -1.406837  0.849172 -10.628519  8.330598e-24  6.908398e-20   42.509871
# ...         ...       ...        ...           ...           ...         ...
# 41459  0.001067  0.148021   0.013399  9.893122e-01  9.985585e-01   -6.737826
# 41460 -0.000931  0.030328  -0.011657  9.907019e-01  9.986675e-01   -6.737838
# 41461 -0.000932  0.096385  -0.011486  9.908387e-01  9.986675e-01   -6.737840
# 41462 -0.000303  0.242820  -0.003851  9.969282e-01  9.996025e-01   -6.737858
# 41463  0.000056 -0.049941   0.000711  9.994331e-01  9.998672e-01   -6.737894
#
#                                               variant_id  \
# 0      cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 1      cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
# 2      cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 3      cardiac_neuro_cava_random:ATR|ENSG00000175054....
# 4      cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
# ...                                                  ...
# 41459  cardiac_neuro_cava_random:NRXN1|ENSG0000017991...
# 41460  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
# 41461  cardiac_neuro_cava_random:FH|ENSG00000091483.8...
# 41462  cardiac_neuro_cava_random:DAOA|ENSG00000182346...
# 41463  cardiac_neuro_cava_random:OXR1|ENSG00000164830...
#
#                                                       ID
# 0      TRIO|ENSG00000038382.23|EH38E2358394|5-1440805...
# 1      ANKZF1|ENSG00000163516.14|EH38E2076021|2-21926...
# 2      TRIO|ENSG00000038382.23|EH38E3627037|5-1425991...
# 3      ATR|ENSG00000175054.16|EH38E3544406|3-14257809...
# 4      CYP2D6|ENSG00000100197.23|EH38E3484163|22-4211...
# ...                                                  ...
# 41459  NRXN1|ENSG00000179915.25|EH38E1997228|2-503360...
# 41460  PHACTR1|ENSG00000112137.19|EH38E2447179|6-1316...
# 41461  FH|ENSG00000091483.8|EH38E2877415|1-241542473-T-C
# 41462  DAOA|ENSG00000182346.22|EH38E3079721|13-105499...
# 41463  OXR1|ENSG00000164830.19|EH38E2655722|8-1067365...
#
# [41464 rows x 8 columns]

# %%
mpra_result.head()
# Out:
#       logFC   AveExpr          t       P.Value     adj.P.Val           B  \
# 0  1.456812  1.860281  16.887425  2.660743e-54  1.103250e-49  111.530180
# 1  1.606197  0.969005  12.616945  9.251426e-32  1.918006e-27   60.057828
# 2  1.531276  0.923153  12.197297  3.871885e-30  5.351462e-26   56.506252
# 3  0.907774  0.994476  11.422970  2.968129e-28  3.076763e-24   53.219004
# 4 -1.406837  0.849172 -10.628519  8.330598e-24  6.908398e-20   42.509871
#
#                                           variant_id  \
# 0  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 1  cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
# 2  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 3  cardiac_neuro_cava_random:ATR|ENSG00000175054....
# 4  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#
#                                                   ID
# 0  TRIO|ENSG00000038382.23|EH38E2358394|5-1440805...
# 1  ANKZF1|ENSG00000163516.14|EH38E2076021|2-21926...
# 2  TRIO|ENSG00000038382.23|EH38E3627037|5-1425991...
# 3  ATR|ENSG00000175054.16|EH38E3544406|3-14257809...
# 4  CYP2D6|ENSG00000100197.23|EH38E3484163|22-4211...

# %%
mpra_result[mpra_result['P.Value'] < 0.05].shape[0] # 3788
# 3788/46000

3788/41284
390/41284
# Out:
# 0.00944675903497723

# %%
# p-value distribution

import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(mpra_result['P.Value'])
plt.xlabel('raw p-value')
plt.show()

# %%
sns.histplot(mpra_result['adj.P.Val'])
plt.xlabel('adj p-value')
plt.show()

# %%
singificants_niveau = 0.05
significant_results = mpra_result[mpra_result['adj.P.Val'] < singificants_niveau]
significant_results.shape
# Out:
# (390, 8)

# %%
significant_results
# Out:
#         logFC   AveExpr          t       P.Value     adj.P.Val           B  \
# 0    1.456812  1.860281  16.887425  2.660743e-54  1.103250e-49  111.530180
# 1    1.606197  0.969005  12.616945  9.251426e-32  1.918006e-27   60.057828
# 2    1.531276  0.923153  12.197297  3.871885e-30  5.351462e-26   56.506252
# 3    0.907774  0.994476  11.422970  2.968129e-28  3.076763e-24   53.219004
# 4   -1.406837  0.849172 -10.628519  8.330598e-24  6.908398e-20   42.509871
# ..        ...       ...        ...           ...           ...         ...
# 398  1.356061  0.150600   3.613225  3.575547e-04  4.039687e-02   -0.407032
# 399 -0.346443  0.174166  -3.553335  4.066853e-04  4.461058e-02   -0.425213
# 400 -0.331786 -0.505080  -3.571911  3.759801e-04  4.190764e-02   -0.434496
# 408 -0.352295 -0.305722  -3.532586  4.373626e-04  4.722605e-02   -0.506139
# 409 -1.683403 -0.124858  -3.738147  2.326406e-04  2.914263e-02   -0.507166
#
#                                             variant_id  \
# 0    cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 1    cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
# 2    cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 3    cardiac_neuro_cava_random:ATR|ENSG00000175054....
# 4    cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
# ..                                                 ...
# 398  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
# 399  cardiac_neuro_cava_random:GRIN2A|ENSG000001834...
# 400  cardiac_neuro_cava_random:MKX|ENSG00000150051....
# 408  cardiac_neuro_cava_random:TMEM115|ENSG00000126...
# 409  cardiac_neuro_cava_random:AHDC1|ENSG0000012670...
#
#                                                     ID
# 0    TRIO|ENSG00000038382.23|EH38E2358394|5-1440805...
# 1    ANKZF1|ENSG00000163516.14|EH38E2076021|2-21926...
# 2    TRIO|ENSG00000038382.23|EH38E3627037|5-1425991...
# 3    ATR|ENSG00000175054.16|EH38E3544406|3-14257809...
# 4    CYP2D6|ENSG00000100197.23|EH38E3484163|22-4211...
# ..                                                 ...
# 398  IRF4|ENSG00000137265.16|EH38E3685036|6-427753-T-C
# 399  GRIN2A|ENSG00000183454.18|EH38E1800740|16-1006...
# 400  MKX|ENSG00000150051.14|EH38E1457204|10-2772505...
# 408  TMEM115|ENSG00000126062.4|EH38E2201056|3-50314...
# 409  AHDC1|ENSG00000126705.15|EH38E2797915|1-275710...
#
# [390 rows x 8 columns]

# %%
# add variant information
merged_variant_file = '/data/gpfs-1/users/kisa11_c/work/coding/MPRA/IGVF_Y1_design/design/MPRA_design/results_5k/merging_variants/merged_prioritized_variants.tsv'
merged_variant_df = pd.read_csv(merged_variant_file, sep='\t')
merged_variant_df
# Out:
#        CHROM        POS                                                 ID  \
# 0       chr1    3030162  PRDM16|ENSG00000142611.17|EH38E1312284|1-30301...
# 1       chr1    3030855  PRDM16|ENSG00000142611.17|EH38E2779521|1-30308...
# 2       chr1    3033425  PRDM16|ENSG00000142611.17|EH38E1312290|1-30334...
# 3       chr1    3033673  PRDM16|ENSG00000142611.17|EH38E2779527|1-30336...
# 4       chr1    3033770  PRDM16|ENSG00000142611.17|EH38E2779527|1-30337...
# ...      ...        ...                                                ...
# 71405   chr6   26284345  H1-3|ENSG00000124575.7|EH38E3697740|6-26284345...
# 71406   chr2  210478202  CPS1|ENSG00000021826.18|EH38E3397495|2-2104782...
# 71407   chr2  210477975  CPS1|ENSG00000021826.18|EH38E3397495|2-2104779...
# 71408   chr2  210478142  CPS1|ENSG00000021826.18|EH38E3397495|2-2104781...
# 71409  chr11    6469152  TIMM10B|ENSG00000132286.12|EH38E1517444|11-646...
#
#       REF ALT  QUAL   FILTER                   INFO gene_type variant_type
# 0       T   A     1     PASS   AF=0.247769;AC=37649   cardiac       common
# 1       G   A     1     PASS  AF=0.0757297;AC=11520   cardiac       common
# 2       A   C     1  AS_VQSR   AF=0.0564555;AC=4921   cardiac       common
# 3       G   A     1     PASS   AF=0.170986;AC=25994   cardiac       common
# 4       G   A     1     PASS   AF=0.171221;AC=26042   cardiac       common
# ...    ..  ..   ...      ...                    ...       ...          ...
# 71405   G   A     1     PASS    AF=6.57903e-06;AC=1    random    singleton
# 71406   C   T     1     PASS     AF=6.5697e-06;AC=1    random    singleton
# 71407   G   C     1     PASS    AF=6.57315e-06;AC=1    random    singleton
# 71408   T   A     1     PASS    AF=6.56858e-06;AC=1    random    singleton
# 71409   G   T     1     PASS    AF=6.56953e-06;AC=1    random    singleton
#
# [71410 rows x 10 columns]

# %%
merged_variant_df[merged_variant_df['variant_type'] == 'common'].shape[0] # common with variant controls 19982
merged_variant_df[merged_variant_df['variant_type'] == 'rare'].shape[0] # rare  16428
merged_variant_df[merged_variant_df['variant_type'] == 'ultra-rare'].shape[0] # ultra-rare 17500
merged_variant_df[merged_variant_df['variant_type'] == 'singleton'].shape[0] # singleton 17500
# Out:
# 17500

# %%
significant_variant_table = significant_results.merge(merged_variant_df, on='ID')
significant_variant_table[~significant_variant_table['gene_type'].isna()].shape[0]
significant_variant_table['abs_logFC'] = significant_variant_table['logFC'].abs()

# %%
# mutiple is fine: associated to two gene_types

common_sig = significant_variant_table[significant_variant_table['variant_type'] == 'common'] # 83
rare_sig = significant_variant_table[significant_variant_table['variant_type'] == 'rare'] # 73
ultra_rare_sig = significant_variant_table[significant_variant_table['variant_type'] == 'ultra-rare'] # 112
singleton_sig = significant_variant_table[significant_variant_table['variant_type'] == 'singleton'] # 130

# %%
common_sig.sort_values('abs_logFC', ascending=False).to_csv('common_sig_results.tsv', sep='\t', index=False)
# common_sig[common_sig['gene_type'] == 'random'].shape[0] # neuro: 50; cardiac: 24, cava: 7, random: 2
# common_sig[common_sig['gene_type'] == 'neuro']

# %%
common_sig[common_sig['gene_type'] == 'neuro'].sort_values('abs_logFC', ascending=False).to_csv('common_sig_neuro_results.tsv', sep='\t', index=False)

# %%
mpra_result.head()
# Out:
#       logFC   AveExpr          t       P.Value     adj.P.Val           B  \
# 0  1.456812  1.860281  16.887425  2.660743e-54  1.103250e-49  111.530180
# 1  1.606197  0.969005  12.616945  9.251426e-32  1.918006e-27   60.057828
# 2  1.531276  0.923153  12.197297  3.871885e-30  5.351462e-26   56.506252
# 3  0.907774  0.994476  11.422970  2.968129e-28  3.076763e-24   53.219004
# 4 -1.406837  0.849172 -10.628519  8.330598e-24  6.908398e-20   42.509871
#
#                                           variant_id  \
# 0  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 1  cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
# 2  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 3  cardiac_neuro_cava_random:ATR|ENSG00000175054....
# 4  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#
#                                                   ID
# 0  TRIO|ENSG00000038382.23|EH38E2358394|5-1440805...
# 1  ANKZF1|ENSG00000163516.14|EH38E2076021|2-21926...
# 2  TRIO|ENSG00000038382.23|EH38E3627037|5-1425991...
# 3  ATR|ENSG00000175054.16|EH38E3544406|3-14257809...
# 4  CYP2D6|ENSG00000100197.23|EH38E3484163|22-4211...

# %%
singificants_niveau = 0.1
significant_results = mpra_result[mpra_result['adj.P.Val'] < singificants_niveau]


# current dataset: significants niveau: 0.05: 390 => ~0.9% significant
# current dataset: significants niveau: 0.1: 511 => ~1.2% significant
# expected according to Mohan: 5% significant

# number of positive and negative results
pos_effect = significant_results[significant_results['logFC'] > 0]
neg_effect = significant_results[significant_results['logFC'] < 0]

n_significant = significant_results.shape[0]
n_positive = pos_effect.shape[0]
n_negative = neg_effect.shape[0]

print('---------- With a significants niveau of %s:----------'%(singificants_niveau))
print('Number of significant results after bc_MPRAlm: %s'%(significant_results.shape[0]))
print('Fraction of significant results: %s'%(round(n_significant / n_tested_vars, 3)))
print('Number of positive effects: %s'%(n_positive))
print('Number of negative effects: %s'%(n_negative))
# Out:
# ---------- With a significants niveau of 0.1:----------
# Number of significant results after bc_MPRAlm: 511
# Fraction of significant results: 0.012
# Number of positive effects: 263
# Number of negative effects: 248

# %% [markdown]
# - Among the significant results how many are in which group? (neuro, cava, cardiac, random?)

# %%
significant_results['label'] = significant_results['variant_id'].apply(lambda x: x.split(':')[0])
# significant_results['label'].value_counts()
# label
# cardiac_neuro_cava_random    510
# GC_Selvarajan                  1

# focus on tested sequences:
tested_sequences = significant_results[significant_results['label'] == 'cardiac_neuro_cava_random']
# Out:
# /tmp/ipykernel_8936/2120465714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   significant_results['label'] = significant_results['variant_id'].apply(lambda x: x.split(':')[0])

# %%
def get_gene_name_from_variant_id(variant_id):
    """Returns the gene name"""
    # cardiac_neuro_cava_random:CDH1|ENSG00000039068.20|EH38E3187943|16-68784390-A-G
    return variant_id.split(':')[1].split('|')[0]

# %%
from collections import defaultdict
# read gene_list files:
gene_list_dir = '/home/kisa/coding/80K_MPRA/MPRA_design/resources/gene_lists'
gene_lists = os.listdir(gene_list_dir)

# goal: I would like to know for each gene in which gene list it is in (neuro, cava, random or cardiac)
# get list of genes you are interested in (look at the significant results and get all gene names)
tested_sequences['gene_name'] = tested_sequences['variant_id'].apply(get_gene_name_from_variant_id)
tested_sequences['gene_name'].nunique() # 238
tested_sequences['abs_log2FC'] = tested_sequences['logFC'].abs()

# tested_sequences['gene_name'].shape # 510
significant_gene_list = list(tested_sequences['gene_name'].unique())
# gene_list



# look them up in the gene lists and remember the information of the gene list name
# count occurences of gene_list_name
gene_list_name_counter = defaultdict(int)
significant_gene_association = defaultdict(list)
for file in gene_lists:
    with open(os.path.join(gene_list_dir, file), 'r') as f:
        gene_list = f.read().splitlines()
        gene_list_name = file.split('.')[0]
        # check if gene is in gene_list
        for gene in significant_gene_list:
            if gene in gene_list:
                significant_gene_association[gene].append(gene_list_name)
                gene_list_name_counter[gene_list_name] += 1

# add this information to tested_sequences
tested_sequences['associated_gene_list'] = tested_sequences['gene_name'].apply(lambda x: significant_gene_association[x])
# find top 3 variants on logFC with neuro in associated_gene_list
top_x = 3
neuro_genes = tested_sequences[tested_sequences['associated_gene_list'].apply(lambda x: 'neuro' in x)]
top_neuro = neuro_genes.sort_values(by='logFC', ascending=False).head(top_x)
low_neuro = neuro_genes.sort_values(by='logFC', ascending=True).head(top_x)
top_neuro # KCNT2, TRIO, MEIS2 (quality control: hi)
top_neuro['ID'].to_list() # KCNT2, TRIO, MEIS2
# low_neuro # NACC1, SKI, AHDC1
# low_neuro['ID'].to_list() # NACC1, SKI, AHDC1

# cava_genes = tested_sequences[tested_sequences['associated_gene_list'].apply(lambda x: 'cava' in x)]
# top_cava = cava_genes.sort_values(by='logFC', ascending=False).head(top_x)
# low_cava = cava_genes.sort_values(by='logFC', ascending=True).head(top_x)
# top_cava['gene_name'].to_list() # ['LMNA', 'MYBPC3', 'IRF4']
# # low_cava['gene_name'].to_list() # ['AHDC1', 'CYP2D6', 'IRF4']
# # low_cava
# cardiac_genes = tested_sequences[tested_sequences['associated_gene_list'].apply(lambda x: 'cardiac' in x)]
# top_cardiac = cardiac_genes.sort_values(by='logFC', ascending=False).head(top_x)
# low_cardiac = cardiac_genes.sort_values(by='logFC', ascending=True).head(top_x)

# top_cardiac['gene_name'].to_list() # ['FLT4', 'GATA4', 'LMNA']
# low_cardiac['gene_name'].to_list() # ['GATA5', 'IRX3', 'NOS1AP']
# Out:
# /tmp/ipykernel_8936/3834475076.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tested_sequences['gene_name'] = tested_sequences['variant_id'].apply(get_gene_name_from_variant_id)
# /tmp/ipykernel_8936/3834475076.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tested_sequences['abs_log2FC'] = tested_sequences['logFC'].abs()
# /tmp/ipykernel_8936/3834475076.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tested_sequences['associated_gene_list'] = tested_sequences['gene_name'].apply(lambda x: significant_gene_association[x])
# ['KCNT2|ENSG00000162687.19|EH38E2855757|1-196494459-G-A',
#  'TRIO|ENSG00000038382.23|EH38E3627037|5-14259916-C-T',
#  'MEIS2|ENSG00000134138.22|EH38E3127695|15-36879863-C-A']

# %%
tested_sequences[tested_sequences['ID'] == 'KCNT2|ENSG00000162687.19|EH38E2855757|1-196494459-G-A']
# Out:
#        logFC   AveExpr         t       P.Value  adj.P.Val         B  \
# 99  1.566669  0.937944  5.370376  1.714164e-07   0.000078  5.978029
#
#                                            variant_id  \
# 99  cardiac_neuro_cava_random:KCNT2|ENSG0000016268...
#
#                                                    ID  \
# 99  KCNT2|ENSG00000162687.19|EH38E2855757|1-196494...
#
#                         label gene_name  abs_log2FC associated_gene_list
# 99  cardiac_neuro_cava_random     KCNT2    1.566669              [neuro]

# %%
significant_gene_association
# Out:
# defaultdict(list,
#             {'TRIO': ['neuro'],
#              'SLC1A2': ['neuro'],
#              'DISC1': ['neuro'],
#              'NCOA1': ['neuro'],
#              'DALRD3': ['neuro'],
#              'NRXN1': ['neuro'],
#              'TLK2': ['neuro'],
#              'WWOX': ['neuro'],
#              'TBL1XR1': ['neuro'],
#              'CUL3': ['neuro'],
#              'RHOBTB2': ['neuro'],
#              'WAC': ['neuro'],
#              'LZTR1': ['neuro'],
#              'SKI': ['neuro'],
#              'FOXP1': ['neuro'],
#              'CHI3L1': ['neuro'],
#              'PNKP': ['neuro'],
#              'DSCAM': ['neuro'],
#              'TM9SF4': ['neuro'],
#              'ARID1B': ['neuro'],
#              'APOL4': ['neuro'],
#              'FOXP2': ['neuro'],
#              'LRRC4C': ['neuro'],
#              'PRR12': ['neuro'],
#              'SOX5': ['neuro'],
#              'MTOR': ['neuro'],
#              'CYFIP2': ['neuro'],
#              'CHAMP1': ['neuro'],
#              'KANSL1': ['neuro'],
#              'EP300': ['neuro'],
#              'CTNNB1': ['neuro', 'cava'],
#              'AHDC1': ['neuro', 'cava'],
#              'ADAM22': ['neuro'],
#              'KCNT2': ['neuro'],
#              'SHANK2': ['neuro'],
#              'PPP3CA': ['neuro'],
#              'HIVEP2': ['neuro'],
#              'PPP5C': ['neuro'],
#              'ANK2': ['neuro'],
#              'VPS13B': ['neuro'],
#              'PHACTR1': ['neuro', 'cardiac'],
#              'TCF7L2': ['neuro'],
#              'CACNA1C': ['neuro', 'cardiac'],
#              'CELF2': ['neuro'],
#              'TCF4': ['neuro'],
#              'TSC1': ['neuro'],
#              'PACS1': ['neuro'],
#              'HTR2A': ['neuro'],
#              'ZNF462': ['neuro'],
#              'CACNA2D3': ['neuro'],
#              'MEIS2': ['neuro'],
#              'SYNJ1': ['neuro'],
#              'RFX3': ['neuro'],
#              'DPYSL2': ['neuro'],
#              'AUTS2': ['neuro'],
#              'HRAS': ['neuro', 'cardiac'],
#              'PARS2': ['neuro'],
#              'PAX5': ['neuro'],
#              'ZNF148': ['neuro'],
#              'MYT1L': ['neuro'],
#              'CAD': ['neuro'],
#              'CELF4': ['neuro'],
#              'BCL11A': ['neuro'],
#              'GABBR2': ['neuro'],
#              'MDH2': ['neuro'],
#              'TNRC6B': ['neuro'],
#              'PPP1R9B': ['neuro'],
#              'TRAK1': ['neuro'],
#              'CDK19': ['neuro'],
#              'HNRNPH2': ['neuro'],
#              'KIAA0232': ['neuro'],
#              'PTEN': ['neuro'],
#              'ASXL3': ['neuro'],
#              'NRXN3': ['neuro'],
#              'PSMD12': ['neuro'],
#              'DRD3': ['neuro'],
#              'FGF12': ['neuro'],
#              'DHCR7': ['neuro'],
#              'SMARCA2': ['neuro'],
#              'PCCB': ['neuro'],
#              'UBR1': ['neuro', 'cardiac'],
#              'SLC12A5': ['neuro'],
#              'KMT5B': ['neuro'],
#              'ANK3': ['neuro'],
#              'KCNQ3': ['neuro'],
#              'NACC1': ['neuro'],
#              'ADSL': ['neuro'],
#              'NBEA': ['neuro'],
#              'RERE': ['neuro'],
#              'ADNP': ['neuro'],
#              'SLC6A1': ['neuro'],
#              'PIGP': ['neuro'],
#              'KMT2E': ['neuro'],
#              'ZNF292': ['neuro'],
#              'YWHAG': ['neuro'],
#              'UGP2': ['neuro'],
#              'MECP2': ['neuro'],
#              'AP3B2': ['neuro'],
#              'AP2S1': ['neuro'],
#              'MBD5': ['neuro'],
#              'CNPY3': ['neuro'],
#              'PACS2': ['neuro'],
#              'ZBTB20': ['neuro'],
#              'SHANK3': ['neuro'],
#              'GRIN2A': ['neuro'],
#              'MKX': ['neuro'],
#              'GNAO1': ['neuro'],
#              'ACTB': ['neuro'],
#              'PLCB1': ['neuro'],
#              'ATP1A2': ['neuro'],
#              'MED13L': ['neuro', 'cardiac'],
#              'CIC': ['neuro'],
#              'ANKRD11': ['neuro'],
#              'IRF2BPL': ['neuro'],
#              'CUX1': ['neuro'],
#              'USP9X': ['neuro'],
#              'APOL2': ['neuro'],
#              'GAD1': ['neuro'],
#              'FRRS1L': ['neuro'],
#              'CHD7': ['neuro'],
#              'TANC2': ['neuro'],
#              'ATR': ['cava'],
#              'CYP2D6': ['cava'],
#              'CDH1': ['cava'],
#              'LMNA': ['cava', 'cardiac'],
#              'RAD51B': ['cava'],
#              'RINT1': ['cava'],
#              'MYBPC3': ['cava', 'cardiac'],
#              'NBN': ['cava'],
#              'ATM': ['cava'],
#              'MALT1': ['cava'],
#              'IRF4': ['cava'],
#              'MAX': ['cava'],
#              'BCL10': ['cava'],
#              'BRCA2': ['cava'],
#              'FH': ['cava'],
#              'SFPQ': ['cava'],
#              'FARS2': ['cava'],
#              'SDHAF2': ['cava'],
#              'CARD11': ['cava'],
#              'G6PD': ['cava'],
#              'FLCN': ['cava'],
#              'CYP2C19': ['cava'],
#              'RAD51D': ['cava'],
#              'MORF4L1': ['cava'],
#              'MYH7': ['cava', 'cardiac'],
#              'FANCI': ['cava'],
#              'SDHC': ['cava'],
#              'SDHB': ['cava'],
#              'SDHA': ['cava'],
#              'SDHD': ['cava'],
#              'FANCM': ['cava'],
#              'ANKZF1': ['random'],
#              'H1-3': ['random'],
#              'R3HDML': ['random'],
#              'LINC01033': ['random'],
#              'LINC01626': ['random'],
#              'HDHD5': ['random'],
#              'PPP2R2A': ['random'],
#              'B3GNT9': ['random'],
#              'HADH': ['random'],
#              'CA8': ['random'],
#              'IGLV3-25': ['random'],
#              'CPS1': ['random'],
#              'CFAP91': ['random'],
#              'CNN3': ['random'],
#              'TMEM115': ['random'],
#              'MOGS': ['random'],
#              'LAMA4': ['cardiac'],
#              'GATA4': ['cardiac'],
#              'ARHGAP31': ['cardiac'],
#              'NOS1AP': ['cardiac'],
#              'CBL': ['cardiac'],
#              'SMAD4': ['cardiac'],
#              'IRX3': ['cardiac'],
#              'MYL2': ['cardiac'],
#              'DMD': ['cardiac'],
#              'RIT1': ['cardiac'],
#              'MYOZ2': ['cardiac'],
#              'CTNNA3': ['cardiac'],
#              'ECE1': ['cardiac'],
#              'FTO': ['cardiac'],
#              'PLPP3': ['cardiac'],
#              'SLC22A5': ['cardiac'],
#              'SMAD2': ['cardiac'],
#              'PRKAG2': ['cardiac'],
#              'EYA4': ['cardiac'],
#              'GJA1': ['cardiac'],
#              'RBM20': ['cardiac'],
#              'PBX1': ['cardiac'],
#              'TMEM43': ['cardiac'],
#              'MYOM1': ['cardiac'],
#              'ANKRD1': ['cardiac'],
#              'PRDM16': ['cardiac'],
#              'TNNI3': ['cardiac'],
#              'NEBL': ['cardiac'],
#              'STAMBP': ['cardiac'],
#              'SOS1': ['cardiac'],
#              'FLT4': ['cardiac'],
#              'ABCC9': ['cardiac'],
#              'PKP2': ['cardiac'],
#              'DTNA': ['cardiac'],
#              'SMAD3': ['cardiac'],
#              'TBX20': ['cardiac'],
#              'DYNC2I1': ['cardiac'],
#              'TAB2': ['cardiac'],
#              'SMAD6': ['cardiac'],
#              'SEMA3E': ['cardiac'],
#              'BAG3': ['cardiac'],
#              'RAF1': ['cardiac'],
#              'JPH2': ['cardiac'],
#              'CASQ2': ['cardiac'],
#              'SH3PXD2B': ['cardiac'],
#              'PITX2': ['cardiac'],
#              'CRYAB': ['cardiac'],
#              'NOTCH2': ['cardiac'],
#              'JAG1': ['cardiac'],
#              'OFD1': ['cardiac'],
#              'CITED2': ['cardiac'],
#              'GATAD1': ['cardiac'],
#              'ACTC1': ['cardiac'],
#              'NOTCH1': ['cardiac'],
#              'TFAP2B': ['cardiac'],
#              'CSRP3': ['cardiac'],
#              'HNF1A': ['cardiac'],
#              'FHL1': ['cardiac'],
#              'GATA6': ['cardiac'],
#              'SHOC2': ['cardiac'],
#              'PDLIM3': ['cardiac'],
#              'JUP': ['cardiac'],
#              'NRAS': ['cardiac'],
#              'MTRR': ['cardiac'],
#              'FBN1': ['cardiac'],
#              'ACVR1': ['cardiac'],
#              'SGCD': ['cardiac'],
#              'GATA5': ['cardiac'],
#              'ALPK3': ['cardiac'],
#              'RYR2': ['cardiac']})

# %%
gene_list_name_counter
# summe = 0
# for key in gene_list_name_counter:
#     summe += gene_list_name_counter[key]
# summe

# plot this information
import matplotlib.pyplot as plt
import seaborn as sns
# plot gene_list_name_counter
# make the whole plot smaller

plt.figure(figsize=(10, 10))
sns.barplot(x=list(gene_list_name_counter.keys()), y=list(gene_list_name_counter.values()))
plt.xticks(rotation=45)
plt.title('Number of significant genes per gene list')
plt.show()

# %%
# check max length of values
max_len = 0
for key, value in significant_gene_association.items():
    if len(value) > max_len:
        max_len = len(value)
        max_gene = key
        max_gene_list = value


# how many elements have 2 values
genes_with_multiple_association = []
two_values = 0
for key, value in significant_gene_association.items():
    if len(value) == 2:
        print(key, value)
        genes_with_multiple_association.append(key)
        two_values += 1

two_values
# Out:
# CTNNB1 ['neuro', 'cava']
# AHDC1 ['neuro', 'cava']
# PHACTR1 ['neuro', 'cardiac']
# CACNA1C ['neuro', 'cardiac']
# HRAS ['neuro', 'cardiac']
# UBR1 ['neuro', 'cardiac']
# MED13L ['neuro', 'cardiac']
# LMNA ['cava', 'cardiac']
# MYBPC3 ['cava', 'cardiac']
# MYH7 ['cava', 'cardiac']
# 10

# %%
genes_with_multiple_association
# Out:
# ['CTNNB1',
#  'AHDC1',
#  'PHACTR1',
#  'CACNA1C',
#  'HRAS',
#  'UBR1',
#  'MED13L',
#  'LMNA',
#  'MYBPC3',
#  'MYH7']

# %%
tested_sequences.head()
# Out:
#       logFC   AveExpr          t       P.Value     adj.P.Val           B  \
# 0  1.456812  1.860281  16.887425  2.660743e-54  1.103250e-49  111.530180
# 1  1.606197  0.969005  12.616945  9.251426e-32  1.918006e-27   60.057828
# 2  1.531276  0.923153  12.197297  3.871885e-30  5.351462e-26   56.506252
# 3  0.907774  0.994476  11.422970  2.968129e-28  3.076763e-24   53.219004
# 4 -1.406837  0.849172 -10.628519  8.330598e-24  6.908398e-20   42.509871
#
#                                           variant_id  \
# 0  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 1  cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
# 2  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 3  cardiac_neuro_cava_random:ATR|ENSG00000175054....
# 4  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#
#                                                   ID  \
# 0  TRIO|ENSG00000038382.23|EH38E2358394|5-1440805...
# 1  ANKZF1|ENSG00000163516.14|EH38E2076021|2-21926...
# 2  TRIO|ENSG00000038382.23|EH38E3627037|5-1425991...
# 3  ATR|ENSG00000175054.16|EH38E3544406|3-14257809...
# 4  CYP2D6|ENSG00000100197.23|EH38E3484163|22-4211...
#
#                        label gene_name  abs_log2FC
# 0  cardiac_neuro_cava_random      TRIO    1.456812
# 1  cardiac_neuro_cava_random    ANKZF1    1.606197
# 2  cardiac_neuro_cava_random      TRIO    1.531276
# 3  cardiac_neuro_cava_random       ATR    0.907774
# 4  cardiac_neuro_cava_random    CYP2D6    1.406837

# %%
# found 10 genes which are in multiple groups
# is their effect positive or negative?

significant_results_of_multiple_association_set = tested_sequences[tested_sequences['gene_name'].isin(genes_with_multiple_association)]
significant_results_of_multiple_association_set.shape

# plot the distribution of absolute logFC for the genes with multiple association and the absolute log2fc of all significant results

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=significant_results_of_multiple_association_set, x='logFC', bins=50, color='black', label='Multiple association')
sns.histplot(data=tested_sequences, x='logFC', bins=50, color='gray', label='All significant results')
plt.legend()
plt.title('Distribution of logFC for the genes with multiple association and the logFC of all significant results')
plt.show()

# %% [markdown]
# #### Add alternative merging possibility with chrom pos ref alt

# %%
def get_chrom_pos_ref_alt(ID):
    """Returns the last part of the ID column (after the last '|')"""
    return ID.split('|')[-1]

# %%
# add chrom pos ref alt column
enformer_class['chrom_pos_ref_alt'] = enformer_class['ID'].apply(get_chrom_pos_ref_alt)
# enformer_class['chrom_pos_ref_alt']
mpra_result['chrom_pos_ref_alt'] = mpra_result['variant_id'].apply(get_chrom_pos_ref_alt)
# mpra_result['chrom_pos_ref_alt']

# %% [markdown]
# ### General summary
# - Number of variants we have prioritized with enformer (all non common variants) (32500: missing random singleton set (+2500))
# - Number of variants we got from MPRAlm (21102 (older version from march 2024))
# - Number of variants we could match
# - Number of variant we could not match
#   - old mpralm: 21102: investigate plot AF distribution (Question: how was the AF information added to the MPRAlm plot) => I sampled these myself in `/data/gpfs-1/users/kisa11_c/work/coding/80K_analysis/04_MPRAlm/enformer_results/reading_enformer_tsv.ipynb`
#   - real data: 41464 tested from bc_MPRAlm; 20541 matchable from enformer class (we have 46458 different variants in total in the design)

# %%
print('Number of variants with information from enformer (prioritized (only non common variants)): %s'%(enformer_class.shape[0]))
#! TODO: get numbers of common variants by getting values from design presentation
# Out:
# Number of variants with information from enformer (prioritized (only non common variants)): 32500

# %%
# show prioritized from enformer variant number per group:
enformer_class[['ID', 'gene_set', 'variant_type']].rename(columns={'ID': 'variant_number'}).groupby(['gene_set', 'variant_type']).count()
# Out:
#                        variant_number
# gene_set variant_type
# cardiac  singleton               5000
#          ultra-rare              5000
# cava     singleton               5000
#          ultra-rare              5000
# neuro    singleton               5000
#          ultra-rare              5000
# random   ultra-rare              2500

# %%
print('Number of variants which were successfully tested with barcode MPRAlm: %s'%(mpra_result.shape[0]))
# Out:
# Number of variants which were successfully tested with barcode MPRAlm: 41464

# %%
matching_column = 'ID'
mpra_enformer_df = mpra_result.merge(enformer_class, on=matching_column, how='left')
mpralm_enformer_matchable = mpra_enformer_df[~mpra_enformer_df['variant_type'].isna()] # 1884 neuro singleton; 8964 all enformer class files
print('The fraction of testable variants in this for this analysis pipeline is: %s'%(round(mpra_enformer_df.shape[0]/total_number_of_variants_in_design,3)))
print('Number of matchable variants between MPRAlm results and enformer class file: %s'%(mpralm_enformer_matchable.shape[0]))
print('The fraction of matchable variants between MPRAlm results and enformer class file: %s'%(round(mpralm_enformer_matchable.shape[0]/mpra_result.shape[0],3)))
print('TODO: with real data: still low number of matchable prioritized variants from enformer class file')
print('TODO: What types of sequences are missing???')
# TODO: investigate with real data if only that few non common variants are in enformer class file
# TODO: what type of sequences are missing?
# get the sequences and number of rows which are not matchable
matched_sequences = mpralm_enformer_matchable[matching_column].to_list()
not_matched_mpralm_results = mpra_result[~mpra_result[matching_column].isin(matched_sequences)]
print('Number of unmatched sequences: %s'%(not_matched_mpralm_results.shape[0]))
not_matched_mpralm_results.head()
# plot the AF distribution of the non matched sequences and mark the median

### old version because old MPRAlm table had AF as column
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_style("whitegrid")
# plt.figure(figsize=(10,6))
# sns.histplot(not_matched_mpralm_results['AF'], bins=50, color='blue')
# plt.axvline(not_matched_mpralm_results['AF'].median(), color='red', linestyle='dashed', linewidth=2)
# plt.title('Allele frequency distribution of non matched sequences')
# plt.xlabel('Allele frequency')
# plt.ylabel('Count')
# plt.show()
# not_matched_mpralm_results['AF'].median() #0.0599
# => many low allele frequency sequences are not in enformer class file
# todo: same with enformer class file not matched
# Out:
# The fraction of testable variants in this for this analysis pipeline is: 0.901
# Number of matchable variants between MPRAlm results and enformer class file: 20541
# The fraction of matchable variants between MPRAlm results and enformer class file: 0.495
# TODO: with real data: still low number of matchable prioritized variants from enformer class file
# TODO: What types of sequences are missing???
# Number of unmatched sequences: 21312
#       logFC   AveExpr          t       P.Value     adj.P.Val          B  \
# 1  1.606197  0.969005  12.616945  9.251426e-32  1.918006e-27  60.057828
# 2  1.531276  0.923153  12.197297  3.871885e-30  5.351462e-26  56.506252
# 6  1.041370  1.150777  10.155316  1.616258e-22  9.573787e-19  40.137264
# 8  1.330451  1.082684   9.629536  5.226375e-20  2.407849e-16  33.977775
# 9 -1.016115  1.123406  -9.194952  6.216913e-19  2.577781e-15  32.046334
#
#                                           variant_id  \
# 1  cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
# 2  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 6  cardiac_neuro_cava_random:SLC1A2|ENSG000001104...
# 8  cardiac_neuro_cava_random:H1-3|ENSG00000124575...
# 9  cardiac_neuro_cava_random:DISC1|ENSG0000016294...
#
#                                                   ID chrom_pos_ref_alt
# 1  ANKZF1|ENSG00000163516.14|EH38E2076021|2-21926...   2-219267001-T-C
# 2  TRIO|ENSG00000038382.23|EH38E3627037|5-1425991...    5-14259916-C-T
# 6  SLC1A2|ENSG00000110436.13|EH38E1532674|11-3528...   11-35289966-C-T
# 8  H1-3|ENSG00000124575.7|EH38E3697725|6-26269112...    6-26269112-G-T
# 9  DISC1|ENSG00000162946.23|EH38E2873486|1-231734...   1-231734633-A-G

# %% [markdown]
# ##### Investigate which rows are not matching from the enformer class
# - 32500 variants are in the enformer class table
# - 23536 are not matchable to the variants in the mpralm table

# %%
matched_sequences = mpralm_enformer_matchable[matching_column].to_list()
not_matched_enformer_class = enformer_class[~enformer_class[matching_column].isin(matched_sequences)]
not_matched_enformer_class.shape[0] # 23536 old MPRAlm results; 11959 new results
# Out:
# 11959

# %%
mpralm_enformer_matchable
mpralm_enformer_matchable['variant_id'].to_list()[0]
# Out:
# 'cardiac_neuro_cava_random:TRIO|ENSG00000038382.23|EH38E2358394|5-14408059-A-G'

# %% [markdown]
# ### Pos negative variants numbers
# - how many of the significant variants can be matched?
# - how many positive and negative variants are there in the enformer class table?
# - how many of the matched variants which are significant have high effect class of enformer?
# - how many of the matched significant effect class have not a high effect class?
# - how many are singleton?
# - how many are ultra rare?

# %%
mpralm_enformer_matchable

matched_significant_results = mpralm_enformer_matchable[mpralm_enformer_matchable['adj.P.Val'] < singificants_niveau]


# current dataset: significants niveau: 0.05: 390 => ~0.9% significant
# current dataset: significants niveau: 0.1: 511 => ~1.2% significant
# expected according to Mohan: 5% significant

# number of positive and negative results
matched_pos_effect = matched_significant_results[matched_significant_results['logFC'] > 0]
matched_neg_effect = matched_significant_results[matched_significant_results['logFC'] < 0]

n_matched_significant = matched_significant_results.shape[0]
n_matched_positive = matched_pos_effect.shape[0]
n_matched_negative = matched_neg_effect.shape[0]
print('---------- With a significants niveau of %s:----------'%(singificants_niveau))
print('Number of significant results after bc_MPRAlm and matching with enformer class file: %s'%(matched_significant_results.shape[0]))
print('Fraction of matchable significant results: %s'%(round(n_matched_significant / n_significant, 3)))
print('This means %s of the significant results could be matched with enformer class information.\n   Which means if everything works perfect the rest of the signifiant effects is from common variants.'%(round(n_matched_significant / n_significant, 3)))
print('Fraction of significant results: %s'%(round(matched_significant_results.shape[0] / n_tested_vars, 3)))
print('Number of positive effects: %s'%(n_matched_positive))
print('Number of negative effects: %s'%(n_matched_negative))

# significant results enformer class distribution

matched_significant_results[['enformer_class', 'ID']].groupby(['enformer_class' ]).count()
# Out:
# ---------- With a significants niveau of 0.1:----------
# Number of significant results after bc_MPRAlm and matching with enformer class file: 295
# Fraction of matchable significant results: 0.577
# This means 0.577 of the significant results could be matched with enformer class information.
#    Which means if everything works perfect the rest of the signifiant effects is from common variants.
# Fraction of significant results: 0.007
# Number of positive effects: 157
# Number of negative effects: 138
#                  ID
# enformer_class
# enformer_high   247
# enformer_low     21
# random           27

# %%
mpralm_enformer_matchable[['enformer_class', 'ID']].groupby(['enformer_class']).count()
# Out:
#                    ID
# enformer_class
# enformer_high   15055
# enformer_low     2584
# random           2902

# %%
significant_high = 247
significant_not_high = 21+27
all_high = 15055
all_not_high = 2584 + 2902
all_values = all_high + all_not_high


total_sig = n_matched_significant
total_non_sig = mpralm_enformer_matchable.shape[0] - n_matched_significant
total_high = all_high
total_non_high = all_not_high
table_total = mpralm_enformer_matchable.shape[0]

# test with chi-square
from scipy.stats import chisquare
observed = [significant_high, significant_not_high, all_high-significant_high, all_not_high-significant_not_high]
expected = [total_sig * total_high / table_total, total_sig * total_non_high / table_total, total_non_sig * total_high / table_total, total_non_sig * total_non_high / table_total]

chisquare(observed, expected) # Power_divergenceResult(statistic=16.65368095903453, pvalue=0.000832623862389024)
print('interpretation: enformer has a huge number of false positives.')
print('This means the distribution of significant results in the enformer class file is significantly different from the distribution of all results in the enformer class file.')
# Out:
# interpretation: enformer has a huge number of false positives.
# This means the distribution of significant results in the enformer class file is significantly different from the distribution of all results in the enformer class file.

# %% [markdown]
# ### Bin analyse

# %%
matched_significant_results
# Out:
#         logFC   AveExpr          t       P.Value     adj.P.Val           B  \
# 0    1.456812  1.860281  16.887425  2.660743e-54  1.103250e-49  111.530180
# 3    0.907774  0.994476  11.422970  2.968129e-28  3.076763e-24   53.219004
# 4   -1.406837  0.849172 -10.628519  8.330598e-24  6.908398e-20   42.509871
# 5    0.972920  1.131691  10.297778  4.061172e-23  2.806541e-19   41.502237
# 7   -0.781395  0.785936  -9.539835  1.554767e-20  8.058356e-17   35.847418
# ..        ...       ...        ...           ...           ...         ...
# 534 -0.297338  0.044220  -3.297080  1.021932e-03  8.665313e-02   -1.326204
# 539  0.323746 -0.102267   3.265319  1.146813e-03  9.510291e-02   -1.348274
# 543 -0.337154 -0.357928  -3.258248  1.179401e-03  9.741572e-02   -1.368861
# 569  0.268013  1.706082   3.251167  1.198541e-03  9.790928e-02   -1.487553
# 579 -0.276957  0.402146  -3.251188  1.195919e-03  9.790928e-02   -1.521772
#
#                                             variant_id  \
# 0    cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# 3    cardiac_neuro_cava_random:ATR|ENSG00000175054....
# 4    cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
# 5    cardiac_neuro_cava_random:CDH1|ENSG00000039068...
# 7    cardiac_neuro_cava_random:TRIO|ENSG00000038382...
# ..                                                 ...
# 534  cardiac_neuro_cava_random:TRAK1|ENSG0000018260...
# 539  cardiac_neuro_cava_random:ATM|ENSG00000149311....
# 543  cardiac_neuro_cava_random:FTO|ENSG00000140718....
# 569  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
# 579  cardiac_neuro_cava_random:FH|ENSG00000091483.8...
#
#                                                     ID chrom_pos_ref_alt_x  \
# 0    TRIO|ENSG00000038382.23|EH38E2358394|5-1440805...      5-14408059-A-G
# 3    ATR|ENSG00000175054.16|EH38E3544406|3-14257809...     3-142578095-C-G
# 4    CYP2D6|ENSG00000100197.23|EH38E3484163|22-4211...     22-42115774-T-C
# 5    CDH1|ENSG00000039068.20|EH38E3187943|16-687843...     16-68784390-A-G
# 7    TRIO|ENSG00000038382.23|EH38E2358394|5-1440808...      5-14408083-G-T
# ..                                                 ...                 ...
# 534  TRAK1|ENSG00000182606.17|EH38E3507932|3-420820...      3-42082014-A-G
# 539  ATM|ENSG00000149311.20|EH38E2982984|11-1082357...    11-108235733-C-T
# 543  FTO|ENSG00000140718.21|EH38E3181345|16-5405100...     16-54051000-T-C
# 569  PHACTR1|ENSG00000112137.19|EH38E2447178|6-1316...      6-13164515-C-T
# 579  FH|ENSG00000091483.8|EH38E1437047|1-241533995-G-A     1-241533995-G-A
#
#     #CHROM  ...  DNase_max                 INDEX_max QUAL  FILTER  \
# 0     chr5  ...  496.12640  109_DNASE:fibroblast of   1.0    PASS
# 3     chr3  ...  359.43910  177_DNASE:CD8-positive,   1.0    PASS
# 4    chr22  ...  282.07270              63_DNASE:CMK  1.0    PASS
# 5    chr16  ...  655.28420  380_DNASE:foreskin melan  1.0    PASS
# 7     chr5  ...  509.98248  100_DNASE:dermis blood v  1.0    PASS
# ..     ...  ...        ...                       ...  ...     ...
# 534   chr3  ...  512.77630          67_DNASE:GM12864  1.0    PASS
# 539  chr11  ...  129.36777  177_DNASE:CD8-positive,   1.0    PASS
# 543  chr16  ...  517.89050  395_DNASE:common myeloid  1.0    PASS
# 569   chr6  ...  321.00555  485_DNASE:bipolar neuron  1.0    PASS
# 579   chr1  ...  195.94583  392_DNASE:CD14-positive   1.0    PASS
#
#                     INFO  gene_set variant_type enformer_class  \
# 0    AF=6.57117e-06;AC=1     neuro    singleton  enformer_high
# 3    AF=4.60054e-05;AC=7      cava   ultra-rare  enformer_high
# 4    AF=6.57281e-06;AC=1      cava    singleton  enformer_high
# 5    AF=6.57851e-06;AC=1      cava    singleton  enformer_high
# 7    AF=6.57013e-06;AC=1     neuro    singleton  enformer_high
# ..                   ...       ...          ...            ...
# 534  AF=1.97179e-05;AC=3     neuro   ultra-rare  enformer_high
# 539  AF=6.57047e-06;AC=1      cava    singleton  enformer_high
# 543  AF=6.56883e-06;AC=1   cardiac    singleton  enformer_high
# 569  AF=0.00022339;AC=34   cardiac   ultra-rare  enformer_high
# 579  AF=6.56789e-06;AC=1      cava    singleton  enformer_high
#
#     chrom_pos_ref_alt_y abs_logFC
# 0        5-14408059-A-G  1.456812
# 3       3-142578095-C-G  0.907774
# 4       22-42115774-T-C  1.406837
# 5       16-68784390-A-G  0.972920
# 7        5-14408083-G-T  0.781395
# ..                  ...       ...
# 534      3-42082014-A-G  0.297338
# 539    11-108235733-C-T  0.323746
# 543     16-54051000-T-C  0.337154
# 569      6-13164515-C-T  0.268013
# 579     1-241533995-G-A  0.276957
#
# [295 rows x 23 columns]

# %%
# sort by logFC
logFC_sorted = matched_significant_results[['logFC', 'variant_id', 'enformer_class', 'variant_type', 'gene_set', 'DNase_max']].sort_values(by='logFC', ascending=True)
matched_significant_results['abs_logFC'] = matched_significant_results['logFC'].abs()
# sort by logFC (absolut value)
abs_logFC_sorted = matched_significant_results[['logFC', 'variant_id', 'enformer_class', 'variant_type', 'gene_set', 'DNase_max', 'abs_logFC']].sort_values(by='abs_logFC', ascending=True)
abs_bins = [abs_logFC_sorted.iloc[i*abs_logFC_sorted.shape[0]//10:(i+1)*abs_logFC_sorted.shape[0]//10] for i in range(10)]

# make equally distant bins of the logFC and plot  number of enformer_high occurences per bin as histogram
bins = [logFC_sorted.iloc[i*logFC_sorted.shape[0]//10:(i+1)*logFC_sorted.shape[0]//10] for i in range(10)]
# # barplot of numbers of enformer_high occurnces in enformer_class column per bin
# [bins[i].describe for i in range(10)]
# # 495 -0.270634  cardiac_neuro_cava_random:BCL10|ENSG0000014286...
# #  569  0.268013  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
# # This means significant logFC is from -0.27 and from 0.27
# Out:
# /tmp/ipykernel_8936/2828688875.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_significant_results['abs_logFC'] = matched_significant_results['logFC'].abs()

# %%
# get min max logFC values of bins like: '<bin_min> - <bin_max>' for each bin
bin_description = [str(round(bin['logFC'].min(), 2)) + ' - ' + str(round(bin['logFC'].max(), 2)) for bin in bins]
abs_bin_description = [str(round(bin['abs_logFC'].min(), 2)) + ' - ' + str(round(bin['abs_logFC'].max(), 2)) for bin in abs_bins]
bin_description
# Out:
# ['-1.72 - -0.9',
#  '-0.88 - -0.65',
#  '-0.64 - -0.5',
#  '-0.5 - -0.35',
#  '-0.35 - 0.35',
#  '0.35 - 0.44',
#  '0.45 - 0.58',
#  '0.58 - 0.76',
#  '0.76 - 0.93',
#  '0.94 - 1.46']

# %%
# histogram of logFC distribution
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
plt.figure(figsize=(10,6))
sns.histplot(logFC_sorted['logFC'], bins=50, color='blue')
# make line at 0.26 and -0.26 and annotate
plt.axvline(0.255, color='red', linestyle='dashed', linewidth=0.8)
plt.axvline(-0.255, color='red', linestyle='dashed', linewidth=0.8)
plt.text(0.26-0.06, 17.5, '0.26', rotation=90)
plt.text(-0.26-0.045, 17.5, '-0.26', rotation=90)

# add title
plt.title('Log2FC distribution of significant results')
# Out:
# Text(0.5, 1.0, 'Log2FC distribution of significant results')

# %%
# plot number_enformer_low and number_enformer_high in same bar plot (for absolut and for range of log2FC values)

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(10)  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

# get the numbers of each group for each bin
number_enformer_high = [bin[bin['enformer_class'] == 'enformer_high'].shape[0] for bin in abs_bins]
number_enformer_low = [bin[bin['enformer_class'] == 'enformer_low'].shape[0] for bin in abs_bins]
number_random = [bin[bin['enformer_class'] == 'random'].shape[0] for bin in abs_bins]
group_numbers = {'enformer_high': number_enformer_high, 'enformer_low': number_enformer_low, 'random': number_random}


# absolut values
fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in group_numbers.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of enformer labels')
# ax.set_title('Enformer label distribution for DNase values along the sorted absolute logFC value')
ax.set_title('Enformer label distribution along the sorted absolute log2FC value')
ax.set_xticks(x + width, abs_bin_description, rotation=45)
ax.set_xlabel('absolut Log2FC bin range')
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 40)

plt.show()


# full range of logFC values
number_enformer_high = [bin[bin['enformer_class'] == 'enformer_high'].shape[0] for bin in bins]
number_enformer_low = [bin[bin['enformer_class'] == 'enformer_low'].shape[0] for bin in bins]
number_random = [bin[bin['enformer_class'] == 'random'].shape[0] for bin in bins]
group_numbers = {'enformer_high': number_enformer_high, 'enformer_low': number_enformer_low, 'random': number_random}

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in group_numbers.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of enformer labels')
# ax.set_title('Enformer label distribution for DNase values along the sorted absolute logFC value')
ax.set_title('Enformer label distribution along the sorted log2FC value')
ax.set_xticks(x + width, bin_description, rotation=45)
ax.set_xlabel('Log2FC bin range')
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 40)

plt.show()

# %%
bins
# Out:
# [        logFC                                         variant_id  \
#  511 -1.723226  cardiac_neuro_cava_random:GATA5|ENSG0000013070...
#  413 -1.683403  cardiac_neuro_cava_random:AHDC1|ENSG0000012670...
#  23  -1.501145  cardiac_neuro_cava_random:NOS1AP|ENSG000001989...
#  532 -1.481455  cardiac_neuro_cava_random:FBN1|ENSG00000166147...
#  142 -1.476512  cardiac_neuro_cava_random:ECE1|ENSG00000117298...
#  4   -1.406837  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#  481 -1.312495  cardiac_neuro_cava_random:GATA5|ENSG0000013070...
#  325 -1.300314  cardiac_neuro_cava_random:SLC6A1|ENSG000001571...
#  178 -1.259631  cardiac_neuro_cava_random:SYNJ1|ENSG0000015908...
#  14  -1.222910  cardiac_neuro_cava_random:LAMA4|ENSG0000011276...
#  12  -1.188018  cardiac_neuro_cava_random:R3HDML|ENSG000001010...
#  42  -1.169550  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  445 -1.158859  cardiac_neuro_cava_random:CACNA1C|ENSG00000151...
#  444 -1.158859  cardiac_neuro_cava_random:CACNA1C|ENSG00000151...
#  41  -1.157362  cardiac_neuro_cava_random:NOS1AP|ENSG000001989...
#  67  -1.145996  cardiac_neuro_cava_random:NOS1AP|ENSG000001989...
#  34  -1.133038  cardiac_neuro_cava_random:NBN|ENSG00000104320....
#  16  -1.087938  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  349 -1.075720  cardiac_neuro_cava_random:FOXP1|ENSG0000011486...
#  294 -1.049938  cardiac_neuro_cava_random:CHAMP1|ENSG000001988...
#  26  -1.012483  cardiac_neuro_cava_random:SMAD4|ENSG0000014164...
#  350 -0.995006  cardiac_neuro_cava_random:NOTCH1|ENSG000001484...
#  46  -0.954324  cardiac_neuro_cava_random:FOXP1|ENSG0000011486...
#  98  -0.933262  cardiac_neuro_cava_random:AHDC1|ENSG0000012670...
#  190 -0.926546  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  261 -0.909628  cardiac_neuro_cava_random:IGLV3-25|ENSG0000021...
#  162 -0.905013  cardiac_neuro_cava_random:SOS1|ENSG00000115904...
#  84  -0.904635  cardiac_neuro_cava_random:CYFIP2|ENSG000000551...
#  69  -0.904170  cardiac_neuro_cava_random:SLC22A5|ENSG00000197...
#
#      enformer_class variant_type gene_set    DNase_max
#  511  enformer_high   ultra-rare  cardiac   571.855960
#  413  enformer_high   ultra-rare     cava   126.123990
#  23   enformer_high    singleton  cardiac   597.350770
#  532  enformer_high   ultra-rare  cardiac  1177.361900
#  142  enformer_high    singleton  cardiac   820.997300
#  4    enformer_high    singleton     cava   282.072700
#  481  enformer_high   ultra-rare  cardiac   333.998050
#  325  enformer_high   ultra-rare    neuro   431.380160
#  178  enformer_high    singleton    neuro   444.712340
#  14   enformer_high    singleton  cardiac   361.280730
#  12   enformer_high   ultra-rare   random   143.457460
#  42   enformer_high    singleton     cava   216.086960
#  445  enformer_high   ultra-rare  cardiac   610.982670
#  444  enformer_high   ultra-rare    neuro   610.982670
#  41   enformer_high   ultra-rare  cardiac   372.252100
#  67   enformer_high   ultra-rare  cardiac   336.199770
#  34   enformer_high   ultra-rare     cava   371.683800
#  16          random   ultra-rare     cava    13.234099
#  349  enformer_high    singleton    neuro   794.520400
#  294   enformer_low    singleton    neuro    -7.859289
#  26   enformer_high    singleton  cardiac   337.748960
#  350  enformer_high   ultra-rare  cardiac   384.765050
#  46   enformer_high    singleton    neuro   925.972660
#  98   enformer_high    singleton     cava   259.667420
#  190  enformer_high   ultra-rare     cava   117.050450
#  261         random   ultra-rare   random    87.877785
#  162  enformer_high   ultra-rare  cardiac   279.153800
#  84   enformer_high    singleton    neuro  2229.067600
#  69          random   ultra-rare  cardiac    55.534195  ,
#          logFC                                         variant_id  \
#  474 -0.883750  cardiac_neuro_cava_random:MOGS|ENSG00000115275...
#  36  -0.878071  cardiac_neuro_cava_random:RHOBTB2|ENSG00000008...
#  60  -0.873899  cardiac_neuro_cava_random:APOL4|ENSG0000010033...
#  279 -0.870842  cardiac_neuro_cava_random:CHAMP1|ENSG000001988...
#  138 -0.870780  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
#  38  -0.839762  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
#  90  -0.823128  cardiac_neuro_cava_random:FH|ENSG00000091483.8...
#  377 -0.795235  cardiac_neuro_cava_random:NRXN3|ENSG0000002164...
#  147 -0.793370  cardiac_neuro_cava_random:HTR2A|ENSG0000010246...
#  7   -0.781395  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
#  428 -0.772786  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  435 -0.772581  cardiac_neuro_cava_random:DYNC2I1|ENSG00000126...
#  163 -0.771971  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  224 -0.771211  cardiac_neuro_cava_random:BAG3|ENSG00000151929...
#  218 -0.763927  cardiac_neuro_cava_random:CTNNB1|ENSG000001680...
#  37  -0.762967  cardiac_neuro_cava_random:MALT1|ENSG0000017217...
#  284 -0.747210  cardiac_neuro_cava_random:CYP2C19|ENSG00000165...
#  80  -0.743508  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  399 -0.720631  cardiac_neuro_cava_random:SLC6A1|ENSG000001571...
#  99  -0.714554  cardiac_neuro_cava_random:ADAM22|ENSG000000082...
#  370 -0.710579  cardiac_neuro_cava_random:SDHB|ENSG00000117118...
#  388 -0.704135  cardiac_neuro_cava_random:SMAD3|ENSG0000016694...
#  104 -0.701203  cardiac_neuro_cava_random:PPP3CA|ENSG000001388...
#  300 -0.695710  cardiac_neuro_cava_random:HTR2A|ENSG0000010246...
#  392 -0.681229  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#  227 -0.678222  cardiac_neuro_cava_random:HTR2A|ENSG0000010246...
#  88  -0.676340  cardiac_neuro_cava_random:RBM20|ENSG0000020386...
#  424 -0.653585  cardiac_neuro_cava_random:SDHD|ENSG00000204370...
#  70  -0.649501  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#  154 -0.646535  cardiac_neuro_cava_random:CARD11|ENSG000001982...
#
#      enformer_class variant_type gene_set    DNase_max
#  474  enformer_high   ultra-rare   random   232.951550
#  36   enformer_high    singleton    neuro   734.960270
#  60   enformer_high   ultra-rare    neuro   594.021600
#  279   enformer_low   ultra-rare    neuro    -3.867383
#  138  enformer_high   ultra-rare  cardiac   358.592740
#  38   enformer_high   ultra-rare    neuro   418.156100
#  90   enformer_high    singleton     cava   314.276400
#  377   enformer_low   ultra-rare    neuro     0.600689
#  147  enformer_high   ultra-rare    neuro   564.413270
#  7    enformer_high    singleton    neuro   509.982480
#  428  enformer_high    singleton     cava   307.759160
#  435  enformer_high    singleton  cardiac   326.746770
#  163  enformer_high   ultra-rare     cava   150.656300
#  224         random    singleton  cardiac    93.201164
#  218  enformer_high    singleton     cava   161.739440
#  37   enformer_high   ultra-rare     cava   193.201690
#  284   enformer_low   ultra-rare     cava     1.609281
#  80   enformer_high   ultra-rare     cava   518.746100
#  399         random    singleton    neuro    11.512431
#  99   enformer_high   ultra-rare    neuro   414.797400
#  370  enformer_high   ultra-rare     cava   323.729340
#  388  enformer_high    singleton  cardiac   608.667800
#  104  enformer_high    singleton    neuro   428.788450
#  300  enformer_high    singleton    neuro  1154.903900
#  392  enformer_high   ultra-rare     cava   119.782684
#  227  enformer_high   ultra-rare    neuro   449.146030
#  88   enformer_high    singleton  cardiac   590.019840
#  424  enformer_high    singleton     cava   491.362880
#  70          random   ultra-rare     cava    12.791988
#  154  enformer_high    singleton     cava   192.874660  ,
#          logFC                                         variant_id  \
#  140 -0.642233  cardiac_neuro_cava_random:FARS2|ENSG0000014598...
#  167 -0.641881  cardiac_neuro_cava_random:CARD11|ENSG000001982...
#  223 -0.641705  cardiac_neuro_cava_random:CACNA1C|ENSG00000151...
#  150 -0.629609  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  411 -0.591981  cardiac_neuro_cava_random:ZNF462|ENSG000001481...
#  112 -0.590611  cardiac_neuro_cava_random:NOS1AP|ENSG000001989...
#  59  -0.583381  cardiac_neuro_cava_random:MAX|ENSG00000125952....
#  122 -0.582479  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
#  123 -0.582479  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
#  169 -0.568646  cardiac_neuro_cava_random:FLT4|ENSG00000037280...
#  415 -0.567066  cardiac_neuro_cava_random:CTNNB1|ENSG000001680...
#  451 -0.563999  cardiac_neuro_cava_random:NRAS|ENSG00000213281...
#  463 -0.557401  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
#  464 -0.557401  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
#  241 -0.549442  cardiac_neuro_cava_random:PPP2R2A|ENSG00000221...
#  341 -0.549196  cardiac_neuro_cava_random:GATAD1|ENSG000001572...
#  379 -0.540478  cardiac_neuro_cava_random:FH|ENSG00000091483.8...
#  236 -0.535926  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
#  416 -0.530909  cardiac_neuro_cava_random:SHOC2|ENSG0000010806...
#  74  -0.523574  cardiac_neuro_cava_random:SMAD2|ENSG0000017538...
#  260 -0.522434  cardiac_neuro_cava_random:UBR1|ENSG00000159459...
#  94  -0.519966  cardiac_neuro_cava_random:MAX|ENSG00000125952....
#  363 -0.516551  cardiac_neuro_cava_random:FARS2|ENSG0000014598...
#  425 -0.513595  cardiac_neuro_cava_random:ARID1B|ENSG000000496...
#  61  -0.513177  cardiac_neuro_cava_random:CTNNA3|ENSG000001832...
#  367 -0.510155  cardiac_neuro_cava_random:SDHC|ENSG00000143252...
#  161 -0.506044  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  230 -0.505698  cardiac_neuro_cava_random:MALT1|ENSG0000017217...
#  249 -0.503969  cardiac_neuro_cava_random:DRD3|ENSG00000151577...
#
#      enformer_class variant_type gene_set    DNase_max
#  140   enformer_low    singleton     cava     1.571630
#  167  enformer_high   ultra-rare     cava   172.997220
#  223  enformer_high   ultra-rare  cardiac   277.898740
#  150  enformer_high   ultra-rare     cava   146.379760
#  411   enformer_low    singleton    neuro     0.759749
#  112         random    singleton  cardiac    10.640438
#  59   enformer_high   ultra-rare     cava   133.926620
#  122  enformer_high   ultra-rare    neuro   960.856200
#  123  enformer_high   ultra-rare  cardiac   960.856200
#  169  enformer_high    singleton  cardiac   396.598540
#  415  enformer_high   ultra-rare     cava   186.509060
#  451   enformer_low   ultra-rare  cardiac     1.099157
#  463  enformer_high   ultra-rare    neuro   518.077500
#  464  enformer_high   ultra-rare  cardiac   518.077500
#  241         random   ultra-rare   random    52.935997
#  341  enformer_high    singleton  cardiac   321.872470
#  379  enformer_high    singleton     cava   233.505720
#  236  enformer_high   ultra-rare    neuro   494.557300
#  416         random   ultra-rare  cardiac    10.750860
#  74   enformer_high   ultra-rare  cardiac   280.561300
#  260  enformer_high    singleton  cardiac   324.632540
#  94   enformer_high   ultra-rare     cava   117.736740
#  363   enformer_low    singleton     cava     0.909799
#  425  enformer_high    singleton    neuro   617.367200
#  61          random   ultra-rare  cardiac    60.218975
#  367  enformer_high    singleton     cava   197.509060
#  161  enformer_high    singleton     cava   143.008420
#  230  enformer_high   ultra-rare     cava   178.422500
#  249  enformer_high   ultra-rare    neuro  1604.305900  ,
#          logFC                                         variant_id  \
#  328 -0.503204  cardiac_neuro_cava_random:FOXP1|ENSG0000011486...
#  335 -0.501152  cardiac_neuro_cava_random:OFD1|ENSG00000046651...
#  57  -0.493276  cardiac_neuro_cava_random:ATR|ENSG00000175054....
#  252 -0.484273  cardiac_neuro_cava_random:SMARCA2|ENSG00000080...
#  157 -0.479364  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  503 -0.472690  cardiac_neuro_cava_random:RYR2|ENSG00000198626...
#  117 -0.470373  cardiac_neuro_cava_random:VPS13B|ENSG000001325...
#  262 -0.463526  cardiac_neuro_cava_random:DPYSL2|ENSG000000929...
#  490 -0.456811  cardiac_neuro_cava_random:DRD3|ENSG00000151577...
#  149 -0.454934  cardiac_neuro_cava_random:SDHAF2|ENSG000001679...
#  244 -0.452147  cardiac_neuro_cava_random:NRXN3|ENSG0000002164...
#  491 -0.435796  cardiac_neuro_cava_random:ATM|ENSG00000149311....
#  455 -0.434092  cardiac_neuro_cava_random:MTRR|ENSG00000124275...
#  460 -0.428790  cardiac_neuro_cava_random:SMARCA2|ENSG00000080...
#  148 -0.424048  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
#  483 -0.413838  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  398 -0.413281  cardiac_neuro_cava_random:CELF2|ENSG0000004874...
#  436 -0.412459  cardiac_neuro_cava_random:SDHB|ENSG00000117118...
#  172 -0.411246  cardiac_neuro_cava_random:CTNNB1|ENSG000001680...
#  426 -0.408440  cardiac_neuro_cava_random:MYH7|ENSG00000092054...
#  204 -0.406224  cardiac_neuro_cava_random:HADH|ENSG00000138796...
#  500 -0.406081  cardiac_neuro_cava_random:PRKAG2|ENSG000001066...
#  315 -0.405188  cardiac_neuro_cava_random:CTNNA3|ENSG000001832...
#  141 -0.399142  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#  466 -0.391074  cardiac_neuro_cava_random:ACVR1|ENSG0000011517...
#  410 -0.388391  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  520 -0.377915  cardiac_neuro_cava_random:NEBL|ENSG00000078114...
#  371 -0.369999  cardiac_neuro_cava_random:FOXP2|ENSG0000012857...
#  306 -0.355294  cardiac_neuro_cava_random:CRYAB|ENSG0000010984...
#  215 -0.354267  cardiac_neuro_cava_random:TNRC6B|ENSG000001003...
#
#      enformer_class variant_type gene_set    DNase_max
#  328  enformer_high    singleton    neuro   491.392730
#  335   enformer_low   ultra-rare  cardiac     0.918903
#  57   enformer_high    singleton     cava   162.409820
#  252  enformer_high   ultra-rare    neuro   497.702730
#  157  enformer_high    singleton     cava   157.491820
#  503         random   ultra-rare  cardiac    57.832745
#  117  enformer_high   ultra-rare    neuro   410.729550
#  262  enformer_high   ultra-rare    neuro  1203.247300
#  490  enformer_high    singleton    neuro   437.006260
#  149  enformer_high    singleton     cava   185.836530
#  244  enformer_high   ultra-rare    neuro   859.859900
#  491  enformer_high   ultra-rare     cava   387.977500
#  455   enformer_low    singleton  cardiac     1.160510
#  460  enformer_high   ultra-rare    neuro   973.575870
#  148  enformer_high    singleton    neuro   481.871550
#  483  enformer_high   ultra-rare     cava   207.284470
#  398         random   ultra-rare    neuro   152.863330
#  436  enformer_high   ultra-rare     cava   209.019070
#  172         random   ultra-rare     cava    10.546633
#  426  enformer_high    singleton     cava   170.945480
#  204  enformer_high   ultra-rare   random   123.679920
#  500  enformer_high   ultra-rare  cardiac   347.836820
#  315   enformer_low   ultra-rare  cardiac     1.162957
#  141  enformer_high    singleton     cava   350.125370
#  466  enformer_high   ultra-rare  cardiac   768.473000
#  410  enformer_high   ultra-rare     cava   114.956130
#  520  enformer_high   ultra-rare  cardiac   835.141660
#  371         random    singleton    neuro   141.494140
#  306         random    singleton  cardiac    20.170540
#  215  enformer_high    singleton    neuro  1334.904300  ,
#          logFC                                         variant_id  \
#  272 -0.352698  cardiac_neuro_cava_random:ATR|ENSG00000175054....
#  281 -0.352208  cardiac_neuro_cava_random:HADH|ENSG00000138796...
#  231 -0.345162  cardiac_neuro_cava_random:HNRNPH2|ENSG00000126...
#  430 -0.344896  cardiac_neuro_cava_random:SMAD2|ENSG0000017538...
#  516 -0.341858  cardiac_neuro_cava_random:FANCI|ENSG0000014052...
#  543 -0.337154  cardiac_neuro_cava_random:FTO|ENSG00000140718....
#  523 -0.333633  cardiac_neuro_cava_random:ABCC9|ENSG0000006943...
#  461 -0.333246  cardiac_neuro_cava_random:LINC01033|ENSG000002...
#  282 -0.333026  cardiac_neuro_cava_random:FTO|ENSG00000140718....
#  404 -0.331786  cardiac_neuro_cava_random:MKX|ENSG00000150051....
#  480 -0.326030  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  499 -0.322875  cardiac_neuro_cava_random:LINC01033|ENSG000002...
#  347 -0.314598  cardiac_neuro_cava_random:ANK3|ENSG00000151150...
#  333 -0.312073  cardiac_neuro_cava_random:ATR|ENSG00000175054....
#  534 -0.297338  cardiac_neuro_cava_random:TRAK1|ENSG0000018260...
#  504 -0.292275  cardiac_neuro_cava_random:CTNNB1|ENSG000001680...
#  502 -0.291755  cardiac_neuro_cava_random:FOXP1|ENSG0000011486...
#  508 -0.288227  cardiac_neuro_cava_random:LAMA4|ENSG0000011276...
#  579 -0.276957  cardiac_neuro_cava_random:FH|ENSG00000091483.8...
#  495 -0.270634  cardiac_neuro_cava_random:BCL10|ENSG0000014286...
#  569  0.268013  cardiac_neuro_cava_random:PHACTR1|ENSG00000112...
#  390  0.284890  cardiac_neuro_cava_random:SLC22A5|ENSG00000197...
#  277  0.313405  cardiac_neuro_cava_random:HADH|ENSG00000138796...
#  531  0.316493  cardiac_neuro_cava_random:TANC2|ENSG0000017092...
#  264  0.316875  cardiac_neuro_cava_random:TBL1XR1|ENSG00000177...
#  539  0.323746  cardiac_neuro_cava_random:ATM|ENSG00000149311....
#  201  0.336680  cardiac_neuro_cava_random:TBX20|ENSG0000016453...
#  221  0.342555  cardiac_neuro_cava_random:FOXP1|ENSG0000011486...
#  434  0.346692  cardiac_neuro_cava_random:MED13L|ENSG000001230...
#
#      enformer_class variant_type gene_set    DNase_max
#  272   enformer_low    singleton     cava     1.452153
#  281  enformer_high   ultra-rare   random   142.593380
#  231  enformer_high   ultra-rare    neuro   443.099980
#  430         random    singleton  cardiac    41.513504
#  516  enformer_high    singleton     cava   138.864300
#  543  enformer_high    singleton  cardiac   517.890500
#  523  enformer_high    singleton  cardiac   518.806640
#  461  enformer_high   ultra-rare   random   104.632070
#  282  enformer_high    singleton  cardiac   392.315160
#  404         random    singleton    neuro    63.031338
#  480  enformer_high   ultra-rare     cava   158.592070
#  499         random   ultra-rare   random    13.943341
#  347  enformer_high    singleton    neuro   470.839420
#  333  enformer_high    singleton     cava   161.534420
#  534  enformer_high   ultra-rare    neuro   512.776300
#  504   enformer_low    singleton     cava     1.392617
#  502  enformer_high   ultra-rare    neuro  1176.482400
#  508  enformer_high   ultra-rare  cardiac   275.986450
#  579  enformer_high    singleton     cava   195.945830
#  495  enformer_high   ultra-rare     cava   241.439590
#  569  enformer_high   ultra-rare  cardiac   321.005550
#  390  enformer_high   ultra-rare  cardiac   499.328980
#  277  enformer_high   ultra-rare   random   169.100660
#  531  enformer_high    singleton    neuro   448.590670
#  264         random   ultra-rare    neuro    26.857246
#  539  enformer_high    singleton     cava   129.367770
#  201   enformer_low    singleton  cardiac     0.703530
#  221  enformer_high    singleton    neuro   680.083740
#  434  enformer_high   ultra-rare  cardiac   881.615500  ,
#          logFC                                         variant_id  \
#  433  0.346692  cardiac_neuro_cava_random:MED13L|ENSG000001230...
#  331  0.360224  cardiac_neuro_cava_random:LINC01033|ENSG000002...
#  338  0.363448  cardiac_neuro_cava_random:CNN3|ENSG00000117519...
#  336  0.369326  cardiac_neuro_cava_random:CITED2|ENSG000001644...
#  320  0.374855  cardiac_neuro_cava_random:ATM|ENSG00000149311....
#  152  0.375871  cardiac_neuro_cava_random:STAMBP|ENSG000001243...
#  160  0.393546  cardiac_neuro_cava_random:G6PD|ENSG00000160211...
#  312  0.395356  cardiac_neuro_cava_random:FOXP2|ENSG0000012857...
#  288  0.398721  cardiac_neuro_cava_random:CDH1|ENSG00000039068...
#  518  0.399329  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  469  0.399561  cardiac_neuro_cava_random:USP9X|ENSG0000012448...
#  421  0.402501  cardiac_neuro_cava_random:CDH1|ENSG00000039068...
#  365  0.405910  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  375  0.407508  cardiac_neuro_cava_random:AP3B2|ENSG0000010372...
#  207  0.412484  cardiac_neuro_cava_random:BCL11A|ENSG000001198...
#  291  0.412625  cardiac_neuro_cava_random:ATM|ENSG00000149311....
#  440  0.418693  cardiac_neuro_cava_random:MOGS|ENSG00000115275...
#  232  0.419799  cardiac_neuro_cava_random:MORF4L1|ENSG00000185...
#  304  0.423409  cardiac_neuro_cava_random:LMNA|ENSG00000160789...
#  107  0.423733  cardiac_neuro_cava_random:MYOM1|ENSG0000010160...
#  133  0.425451  cardiac_neuro_cava_random:TCF4|ENSG00000196628...
#  477  0.426074  cardiac_neuro_cava_random:CTNNA3|ENSG000001832...
#  271  0.428536  cardiac_neuro_cava_random:MAX|ENSG00000125952....
#  202  0.428881  cardiac_neuro_cava_random:PRDM16|ENSG000001426...
#  321  0.432366  cardiac_neuro_cava_random:SLC1A2|ENSG000001104...
#  303  0.432598  cardiac_neuro_cava_random:NBEA|ENSG00000172915...
#  119  0.439487  cardiac_neuro_cava_random:LMNA|ENSG00000160789...
#  118  0.439487  cardiac_neuro_cava_random:LMNA|ENSG00000160789...
#  387  0.440916  cardiac_neuro_cava_random:SHANK3|ENSG000002513...
#  78   0.443547  cardiac_neuro_cava_random:BCL10|ENSG0000014286...
#
#      enformer_class variant_type gene_set    DNase_max
#  433  enformer_high   ultra-rare    neuro   881.615500
#  331  enformer_high   ultra-rare   random   147.626250
#  338  enformer_high   ultra-rare   random   149.294700
#  336  enformer_high    singleton  cardiac   925.275940
#  320  enformer_high    singleton     cava   144.862580
#  152  enformer_high    singleton  cardiac   396.857880
#  160  enformer_high   ultra-rare     cava   200.970750
#  312  enformer_high   ultra-rare    neuro   649.529400
#  288  enformer_high   ultra-rare     cava   276.033400
#  518  enformer_high    singleton     cava   194.319350
#  469  enformer_high   ultra-rare    neuro   771.905940
#  421  enformer_high    singleton     cava   323.351650
#  365  enformer_high   ultra-rare     cava   120.202040
#  375  enformer_high    singleton    neuro   520.517400
#  207  enformer_high    singleton    neuro   797.579830
#  291  enformer_high   ultra-rare     cava   144.216280
#  440  enformer_high   ultra-rare   random   137.441940
#  232  enformer_high    singleton     cava   131.025880
#  304  enformer_high    singleton     cava   168.593050
#  107  enformer_high    singleton  cardiac   317.095200
#  133  enformer_high   ultra-rare    neuro   518.653800
#  477   enformer_low    singleton  cardiac     1.152742
#  271  enformer_high    singleton     cava   224.473980
#  202  enformer_high    singleton  cardiac  2058.040300
#  321  enformer_high   ultra-rare    neuro   712.670840
#  303  enformer_high    singleton    neuro   468.818970
#  119  enformer_high    singleton  cardiac   461.860170
#  118  enformer_high    singleton     cava   461.860170
#  387  enformer_high    singleton    neuro  1145.713100
#  78   enformer_high    singleton     cava   125.394900  ,
#          logFC                                         variant_id  \
#  364  0.448461  cardiac_neuro_cava_random:GATA4|ENSG0000013657...
#  184  0.463232  cardiac_neuro_cava_random:DPYSL2|ENSG000000929...
#  246  0.473376  cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
#  197  0.474016  cardiac_neuro_cava_random:ZNF148|ENSG000001638...
#  443  0.477086  cardiac_neuro_cava_random:IRF2BPL|ENSG00000119...
#  476  0.477912  cardiac_neuro_cava_random:ZNF148|ENSG000001638...
#  470  0.488794  cardiac_neuro_cava_random:GABBR2|ENSG000001369...
#  339  0.492265  cardiac_neuro_cava_random:KMT2E|ENSG0000000548...
#  238  0.494848  cardiac_neuro_cava_random:RAF1|ENSG00000132155...
#  438  0.495070  cardiac_neuro_cava_random:JUP|ENSG00000173801....
#  280  0.501328  cardiac_neuro_cava_random:ANK3|ENSG00000151150...
#  344  0.502939  cardiac_neuro_cava_random:CA8|ENSG00000178538....
#  177  0.503243  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  216  0.508548  cardiac_neuro_cava_random:RAD51D|ENSG000001853...
#  374  0.517812  cardiac_neuro_cava_random:MECP2|ENSG0000016905...
#  183  0.520892  cardiac_neuro_cava_random:DTNA|ENSG00000134769...
#  254  0.524324  cardiac_neuro_cava_random:SMAD4|ENSG0000014164...
#  381  0.524387  cardiac_neuro_cava_random:IGLV3-25|ENSG0000021...
#  270  0.542525  cardiac_neuro_cava_random:ZNF148|ENSG000001638...
#  126  0.544066  cardiac_neuro_cava_random:FOXP1|ENSG0000011486...
#  414  0.545015  cardiac_neuro_cava_random:GATA6|ENSG0000014144...
#  82   0.546291  cardiac_neuro_cava_random:RIT1|ENSG00000143622...
#  49   0.550240  cardiac_neuro_cava_random:RIT1|ENSG00000143622...
#  143  0.551840  cardiac_neuro_cava_random:PACS1|ENSG0000017511...
#  186  0.556108  cardiac_neuro_cava_random:AUTS2|ENSG0000015832...
#  442  0.559081  cardiac_neuro_cava_random:ANKRD11|ENSG00000167...
#  278  0.573213  cardiac_neuro_cava_random:SMAD6|ENSG0000013783...
#  342  0.576368  cardiac_neuro_cava_random:ZNF292|ENSG000001889...
#  408  0.576742  cardiac_neuro_cava_random:FHL1|ENSG00000022267...
#
#      enformer_class variant_type gene_set   DNase_max
#  364  enformer_high    singleton  cardiac   333.52954
#  184  enformer_high    singleton    neuro   640.62580
#  246  enformer_high   ultra-rare   random   108.08698
#  197  enformer_high   ultra-rare    neuro   438.79620
#  443  enformer_high    singleton    neuro   621.69653
#  476  enformer_high    singleton    neuro   624.91080
#  470  enformer_high    singleton    neuro   427.39578
#  339  enformer_high    singleton    neuro   543.55170
#  238         random    singleton  cardiac    75.91382
#  438  enformer_high    singleton  cardiac   367.40000
#  280  enformer_high   ultra-rare    neuro   408.54797
#  344  enformer_high   ultra-rare   random   117.73898
#  177  enformer_high   ultra-rare     cava   179.70207
#  216  enformer_high    singleton     cava   135.94109
#  374  enformer_high   ultra-rare    neuro   456.11530
#  183  enformer_high   ultra-rare  cardiac   281.21503
#  254         random    singleton  cardiac    93.22957
#  381  enformer_high   ultra-rare   random   233.90149
#  270  enformer_high   ultra-rare    neuro   504.74844
#  126  enformer_high   ultra-rare    neuro   517.19750
#  414  enformer_high   ultra-rare  cardiac   407.75864
#  82   enformer_high    singleton  cardiac   339.12660
#  49   enformer_high   ultra-rare  cardiac  1650.33520
#  143  enformer_high   ultra-rare    neuro   643.53610
#  186  enformer_high    singleton    neuro  3081.38400
#  442  enformer_high    singleton    neuro   512.62897
#  278  enformer_high    singleton  cardiac   878.55475
#  342         random   ultra-rare    neuro     9.23925
#  408  enformer_high    singleton  cardiac   624.03925  ,
#          logFC                                         variant_id  \
#  345  0.577162  cardiac_neuro_cava_random:ACTC1|ENSG0000015925...
#  129  0.585444  cardiac_neuro_cava_random:LINC01626|ENSG000002...
#  383  0.586360  cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
#  318  0.590173  cardiac_neuro_cava_random:TMEM43|ENSG000001708...
#  287  0.593848  cardiac_neuro_cava_random:SMAD3|ENSG0000016694...
#  56   0.606702  cardiac_neuro_cava_random:MYOZ2|ENSG0000017239...
#  144  0.610974  cardiac_neuro_cava_random:ATR|ENSG00000175054....
#  96   0.619203  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  40   0.620666  cardiac_neuro_cava_random:WAC|ENSG00000095787....
#  258  0.628744  cardiac_neuro_cava_random:MALT1|ENSG0000017217...
#  297  0.636861  cardiac_neuro_cava_random:SH3PXD2B|ENSG0000017...
#  29   0.651521  cardiac_neuro_cava_random:TBL1XR1|ENSG00000177...
#  139  0.652165  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
#  97   0.666388  cardiac_neuro_cava_random:PBX1|ENSG00000185630...
#  137  0.679551  cardiac_neuro_cava_random:HIVEP2|ENSG000000108...
#  391  0.685898  cardiac_neuro_cava_random:ARID1B|ENSG000000496...
#  380  0.688465  cardiac_neuro_cava_random:MBD5|ENSG00000204406...
#  355  0.688489  cardiac_neuro_cava_random:YWHAG|ENSG0000017002...
#  22   0.693746  cardiac_neuro_cava_random:ARHGAP31|ENSG0000003...
#  81   0.699233  cardiac_neuro_cava_random:EYA4|ENSG00000112319...
#  68   0.701691  cardiac_neuro_cava_random:PRR12|ENSG0000012646...
#  214  0.704860  cardiac_neuro_cava_random:SEMA3E|ENSG000001703...
#  83   0.706476  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  479  0.713182  cardiac_neuro_cava_random:MEIS2|ENSG0000013413...
#  210  0.731555  cardiac_neuro_cava_random:MDH2|ENSG00000146701...
#  85   0.740430  cardiac_neuro_cava_random:BRCA2|ENSG0000013961...
#  394  0.742667  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  384  0.750531  cardiac_neuro_cava_random:FOXP2|ENSG0000012857...
#  24   0.759220  cardiac_neuro_cava_random:CBL|ENSG00000110395....
#  159  0.759975  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#
#      enformer_class variant_type gene_set    DNase_max
#  345  enformer_high    singleton  cardiac   703.621800
#  129  enformer_high   ultra-rare   random   146.841280
#  383  enformer_high   ultra-rare   random   152.537810
#  318  enformer_high    singleton  cardiac   608.373000
#  287  enformer_high   ultra-rare  cardiac   354.688050
#  56   enformer_high   ultra-rare  cardiac   337.591830
#  144   enformer_low    singleton     cava     1.401566
#  96   enformer_high    singleton     cava   127.739400
#  40   enformer_high   ultra-rare    neuro   415.378500
#  258  enformer_high    singleton     cava   139.600000
#  297  enformer_high   ultra-rare  cardiac   284.485570
#  29   enformer_high   ultra-rare    neuro   418.811370
#  139         random   ultra-rare    neuro    29.000322
#  97   enformer_high   ultra-rare  cardiac  1400.911000
#  137  enformer_high    singleton    neuro   988.341300
#  391  enformer_high    singleton    neuro   670.218100
#  380   enformer_low    singleton    neuro     0.653214
#  355  enformer_high    singleton    neuro   413.073500
#  22   enformer_high    singleton  cardiac   492.136900
#  81   enformer_high   ultra-rare  cardiac   369.234500
#  68   enformer_high    singleton    neuro   471.850980
#  214         random    singleton  cardiac    48.749447
#  83   enformer_high    singleton     cava   165.560530
#  479  enformer_high   ultra-rare    neuro   639.539500
#  210  enformer_high   ultra-rare    neuro   513.938900
#  85   enformer_high   ultra-rare     cava   118.987885
#  394  enformer_high   ultra-rare     cava   125.293540
#  384  enformer_high   ultra-rare    neuro  1211.425500
#  24          random   ultra-rare  cardiac    16.683426
#  159  enformer_high   ultra-rare     cava   149.687760  ,
#          logFC                                         variant_id  \
#  64   0.761974  cardiac_neuro_cava_random:FTO|ENSG00000140718....
#  212  0.762968  cardiac_neuro_cava_random:ANKZF1|ENSG000001635...
#  302  0.765511  cardiac_neuro_cava_random:ADSL|ENSG00000239900...
#  209  0.770220  cardiac_neuro_cava_random:GABBR2|ENSG000001369...
#  134  0.772484  cardiac_neuro_cava_random:TSC1|ENSG00000165699...
#  71   0.789274  cardiac_neuro_cava_random:LAMA4|ENSG0000011276...
#  105  0.789796  cardiac_neuro_cava_random:HDHD5|ENSG0000006999...
#  130  0.790192  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  174  0.795188  cardiac_neuro_cava_random:CHI3L1|ENSG000001330...
#  386  0.811535  cardiac_neuro_cava_random:ZBTB20|ENSG000001817...
#  332  0.815180  cardiac_neuro_cava_random:CHAMP1|ENSG000001988...
#  276  0.818488  cardiac_neuro_cava_random:KMT5B|ENSG0000011006...
#  50   0.834483  cardiac_neuro_cava_random:PNKP|ENSG00000039650...
#  400  0.834498  cardiac_neuro_cava_random:SHANK2|ENSG000001621...
#  310  0.842020  cardiac_neuro_cava_random:FANCI|ENSG0000014052...
#  31   0.850590  cardiac_neuro_cava_random:RINT1|ENSG0000013524...
#  113  0.852738  cardiac_neuro_cava_random:NBN|ENSG00000104320....
#  35   0.869061  cardiac_neuro_cava_random:ATM|ENSG00000149311....
#  92   0.871049  cardiac_neuro_cava_random:LZTR1|ENSG0000009994...
#  181  0.890313  cardiac_neuro_cava_random:RFX3|ENSG00000080298...
#  259  0.897265  cardiac_neuro_cava_random:DMD|ENSG00000198947....
#  185  0.897488  cardiac_neuro_cava_random:SMAD3|ENSG0000016694...
#  156  0.898913  cardiac_neuro_cava_random:VPS13B|ENSG000001325...
#  124  0.904334  cardiac_neuro_cava_random:ANKRD1|ENSG000001486...
#  3    0.907774  cardiac_neuro_cava_random:ATR|ENSG00000175054....
#  292  0.913520  cardiac_neuro_cava_random:MYH7|ENSG00000092054...
#  293  0.913520  cardiac_neuro_cava_random:MYH7|ENSG00000092054...
#  95   0.920402  cardiac_neuro_cava_random:CTNNB1|ENSG000001680...
#  44   0.934456  cardiac_neuro_cava_random:SKI|ENSG00000157933....
#
#      enformer_class variant_type gene_set    DNase_max
#  64   enformer_high    singleton  cardiac   323.560820
#  212  enformer_high   ultra-rare   random   150.515720
#  302  enformer_high    singleton    neuro   429.126300
#  209  enformer_high   ultra-rare    neuro   481.377720
#  134  enformer_high   ultra-rare    neuro  1264.922700
#  71   enformer_high    singleton  cardiac   430.142640
#  105  enformer_high   ultra-rare   random   199.368320
#  130         random    singleton     cava    14.060133
#  174  enformer_high   ultra-rare    neuro   458.040070
#  386  enformer_high   ultra-rare    neuro   919.246800
#  332  enformer_high   ultra-rare    neuro   916.972660
#  276  enformer_high   ultra-rare    neuro   408.409030
#  50   enformer_high    singleton    neuro   419.861240
#  400  enformer_high   ultra-rare    neuro   461.937840
#  310  enformer_high    singleton     cava   138.059800
#  31   enformer_high   ultra-rare     cava   268.468960
#  113  enformer_high    singleton     cava   396.010680
#  35    enformer_low    singleton     cava     0.751415
#  92   enformer_high   ultra-rare    neuro   422.587250
#  181  enformer_high   ultra-rare    neuro   437.245540
#  259  enformer_high   ultra-rare  cardiac   314.021640
#  185  enformer_high    singleton  cardiac   355.849700
#  156  enformer_high    singleton    neuro   563.256900
#  124  enformer_high    singleton  cardiac   371.964020
#  3    enformer_high   ultra-rare     cava   359.439100
#  292   enformer_low    singleton     cava     0.887055
#  293   enformer_low    singleton  cardiac     0.887055
#  95   enformer_high    singleton     cava   159.284030
#  44   enformer_high   ultra-rare    neuro   426.207340  ,
#          logFC                                         variant_id  \
#  131  0.944595  cardiac_neuro_cava_random:CACNA1C|ENSG00000151...
#  448  0.949155  cardiac_neuro_cava_random:SDHB|ENSG00000117118...
#  405  0.959676  cardiac_neuro_cava_random:TAB2|ENSG00000055208...
#  396  0.969587  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#  5    0.972920  cardiac_neuro_cava_random:CDH1|ENSG00000039068...
#  106  0.988159  cardiac_neuro_cava_random:LZTR1|ENSG0000009994...
#  194  1.003420  cardiac_neuro_cava_random:FOXP2|ENSG0000012857...
#  225  1.007776  cardiac_neuro_cava_random:CYP2D6|ENSG000001001...
#  373  1.010982  cardiac_neuro_cava_random:HNF1A|ENSG0000013510...
#  66   1.014988  cardiac_neuro_cava_random:PLPP3|ENSG0000016240...
#  164  1.045811  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  127  1.051709  cardiac_neuro_cava_random:MAX|ENSG00000125952....
#  222  1.067353  cardiac_neuro_cava_random:TRAK1|ENSG0000018260...
#  47   1.094420  cardiac_neuro_cava_random:CHI3L1|ENSG000001330...
#  437  1.097493  cardiac_neuro_cava_random:CIC|ENSG00000079432....
#  368  1.106377  cardiac_neuro_cava_random:SDHB|ENSG00000117118...
#  266  1.128804  cardiac_neuro_cava_random:RAD51B|ENSG000001821...
#  323  1.143798  cardiac_neuro_cava_random:IRF4|ENSG00000137265...
#  43   1.198179  cardiac_neuro_cava_random:LZTR1|ENSG0000009994...
#  450  1.236568  cardiac_neuro_cava_random:ATR|ENSG00000175054....
#  45   1.237481  cardiac_neuro_cava_random:LAMA4|ENSG0000011276...
#  73   1.239365  cardiac_neuro_cava_random:LZTR1|ENSG0000009994...
#  19   1.255044  cardiac_neuro_cava_random:DALRD3|ENSG000001781...
#  189  1.260201  cardiac_neuro_cava_random:KCNT2|ENSG0000016268...
#  191  1.293028  cardiac_neuro_cava_random:FLCN|ENSG00000154803...
#  48   1.361635  cardiac_neuro_cava_random:DMD|ENSG00000198947....
#  32   1.376232  cardiac_neuro_cava_random:MYBPC3|ENSG000001345...
#  11   1.455633  cardiac_neuro_cava_random:LMNA|ENSG00000160789...
#  10   1.455633  cardiac_neuro_cava_random:LMNA|ENSG00000160789...
#  0    1.456812  cardiac_neuro_cava_random:TRIO|ENSG00000038382...
#
#      enformer_class variant_type gene_set    DNase_max
#  131         random   ultra-rare  cardiac    71.830570
#  448  enformer_high   ultra-rare     cava   688.242430
#  405  enformer_high    singleton  cardiac   370.549000
#  396  enformer_high    singleton     cava   142.446580
#  5    enformer_high    singleton     cava   655.284200
#  106  enformer_high   ultra-rare    neuro   496.394960
#  194  enformer_high   ultra-rare    neuro  1113.198400
#  225  enformer_high    singleton     cava   309.791840
#  373  enformer_high   ultra-rare  cardiac   489.395400
#  66   enformer_high    singleton  cardiac   414.472400
#  164  enformer_high    singleton     cava   202.668600
#  127  enformer_high    singleton     cava   436.920350
#  222  enformer_high    singleton    neuro   537.392330
#  47   enformer_high    singleton    neuro   592.390440
#  437   enformer_low    singleton    neuro     0.737347
#  368  enformer_high   ultra-rare     cava  1313.468900
#  266  enformer_high   ultra-rare     cava   229.970690
#  323  enformer_high   ultra-rare     cava   275.623470
#  43   enformer_high   ultra-rare    neuro   668.855960
#  450  enformer_high    singleton     cava   615.406100
#  45   enformer_high   ultra-rare  cardiac   330.958300
#  73   enformer_high   ultra-rare    neuro   608.586500
#  19   enformer_high    singleton    neuro   639.248400
#  189  enformer_high    singleton    neuro   506.237340
#  191  enformer_high    singleton     cava   383.919800
#  48   enformer_high    singleton  cardiac   367.107030
#  32   enformer_high    singleton     cava   186.522320
#  11   enformer_high    singleton  cardiac   452.780100
#  10   enformer_high    singleton     cava   452.780100
#  0    enformer_high    singleton    neuro   496.126400  ]

# %%
# get for each enformer class the corresponding DNase max value per bin
dnase_max_enformer_high = [round(bin.loc[bin['enformer_class'] == 'enformer_high']['DNase_max'].max(), 2) for bin in bins]
dnase_max_enformer_low = [round(bin.loc[bin['enformer_class'] == 'enformer_low']['DNase_max'].max(), 2) for bin in bins]
dnase_max_random = [round(bin.loc[bin['enformer_class'] == 'random']['DNase_max'].max(), 2) for bin in bins]
dnase_min_enformer_high = [round(bin.loc[bin['enformer_class'] == 'enformer_high']['DNase_max'].min(), 2) for bin in bins]
dnase_min_enformer_low = [round(bin.loc[bin['enformer_class'] == 'enformer_low']['DNase_max'].min(), 2) for bin in bins]
dnase_min_random = [round(bin.loc[bin['enformer_class'] == 'random']['DNase_max'].min(), 2) for bin in bins]
dnase_median_enformer_high = [round(bin.loc[bin['enformer_class'] == 'enformer_high']['DNase_max'].median(), 2) for bin in bins]
dnase_median_enformer_low = [round(bin.loc[bin['enformer_class'] == 'enformer_low']['DNase_max'].median(), 2) for bin in bins]
dnase_median_random = [round(bin.loc[bin['enformer_class'] == 'random']['DNase_max'].median(), 2) for bin in bins]

group_dnase_maxs = {'enformer_high': dnase_max_enformer_high, 'enformer_low': dnase_max_enformer_low, 'random': dnase_max_random}
group_dnase_mins = {'enformer_high': dnase_min_enformer_high, 'enformer_low': dnase_min_enformer_low, 'random': dnase_min_random}
group_dnase_medians = {'enformer_high': dnase_median_enformer_high, 'enformer_low': dnase_median_enformer_low, 'random': dnase_median_random}
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(10)  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in group_dnase_mins.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3, rotation=90)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of enformer labels')
ax.set_title('Enformer DNase value for each enformer prediction class along the sorted logFC value')
ax.set_xticks(x + width, bin_description, rotation=45)
ax.set_xlabel('LogFC bin range')
ax.legend(loc='upper left', ncols=3)
# ax.set_ylim(0, 600) # for dnase_max.median()
ax.set_ylim(0, 200) # for dnase_max.min()
# ax.set_ylim(0, 4300) # for dnase_max.max()

plt.show()

# %%
from scipy.stats import chi2_contingency, chi2, chisquare
# contingency table
table = [[significant_high, all_high], [significant_not_high, all_not_high]]
stat, p, dof, expected = chi2_contingency(table)
print('dof=%d' % dof)
print(expected)

# interpret test-statistic
prob = 0.95
critical = chi2.ppf(prob, dof)

critical

# %% [markdown]
# #### Cell type analysis

# %%
matched_significant_results[['gene_set',  'ID']].groupby(['gene_set']).count()
# Out:
#            ID
# gene_set
# cardiac    85
# cava       90
# neuro     101
# random     19

# %% [markdown]
# #### Advanced analysis with cell-type, variant type and enformer class of the significant results

# %%
matched_significant_results[['gene_set', 'variant_type', 'enformer_class', 'ID']].groupby(['gene_set', 'variant_type', 'enformer_class' ]).count()
# Out:
#                                       ID
# gene_set variant_type enformer_class
# cardiac  singleton    enformer_high   34
#                       enformer_low     4
#                       random           7
#          ultra-rare   enformer_high   31
#                       enformer_low     3
#                       random           6
# cava     singleton    enformer_high   44
#                       enformer_low     7
#                       random           1
#          ultra-rare   enformer_high   34
#                       enformer_low     1
#                       random           3
# neuro    singleton    enformer_high   39
#                       enformer_low     4
#                       random           3
#          ultra-rare   enformer_high   49
#                       enformer_low     2
#                       random           4
# random   ultra-rare   enformer_high   16
#                       random           3

# %% [markdown]
# ### Supplementary

# %% [markdown]
# ##### Testing to plot a table from the data while changing the column name: not really working

# %%
# test: (Does not look good:)
import matplotlib.pyplot as plt
# Group by 'Category' and count values
result = enformer_class[['ID', 'gene_set', 'variant_type', 'enformer_class']].groupby(['gene_set', 'variant_type']).count()

# Rename the column
result = result.rename(columns={'ID': 'variant_number'})

# Plot as a table using matplotlib
plt.figure(figsize=(8, 6))
plt.table(cellText=result.values,
          colLabels=result.columns,
          rowLabels=result.index,
          loc='center')
plt.axis('off')
plt.show()
